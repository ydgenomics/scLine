# %% [markdown]
# # Tutorial on single-cell trajectory alignment using Genes2Genes
#
# Genes2Genes (G2G) aims to guide downstream comparative analysis of single-cell reference and query systems along any axis of progression (e.g. differentiation pseudotime, disease/treatment response pseudotime etc.). This notebook describes how we can use G2G framework to infer and analyse gene-level trajectory alignments between a given reference and query dataset.
#
# In this tutorial, we are going to compare trajectories between two treatment groups (PAM and LPS) of mouse bone marrow-derived dendritic cells from Shalek et al (2014). The single cell datasets and their pseudotime estimates were downloaded from https://github.com/shenorrLab/cellAlign (Alpert et al 2018) and packaged into adata objects. There are 2 gene modules: global (core antiviral module) and local (peaked inflammatory module) considered by Alpert et al (2018), and we use the local module as an example comparison.

# %% [markdown]
# - **Brief:** 两个标准化后且有时序信息的h5ad的共有hvgs做时序轨迹比较
# - **Log:** 250923

# %%
import os
import anndata
import numpy as np
import pandas as pd
import seaborn as sb
import numpy as np
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

from genes2genes import Main
from genes2genes import ClusterUtils
from genes2genes import TimeSeriesPreprocessor
from genes2genes import PathwayAnalyser
from genes2genes import VisualUtils
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-8b10dkq1 because the default path (/home/stereonote/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# ### Load anndata reference and query objects
#
# Make sure that each adata object has: <br>
# (1) log normalized gene expression in `adata.X` <br>
# (2) pseudotime estimates in `adata.obs['time']`

# %%
print(os.getcwd())
# Out:
# /data/work/cotton/genes2genes/TEST3

# %%
adata_ref = anndata.read_h5ad(h5ad_ref) # Reference dataset
adata_query = anndata.read_h5ad(h5ad_query) # Query dataset
prefix_ref = os.path.splitext(os.path.basename(h5ad_ref))[0]
prefix_query = os.path.splitext(os.path.basename(h5ad_query))[0]

# %%
print(adata_ref); print(adata_query)
# Out:
# AnnData object with n_obs × n_vars = 537 × 27363
#     obs: 'nCount_RNA', 'nFeature_RNA', 'new_index', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'n_genes', 'doublet_score', 'leiden', 'leiden_res_0.20', 'leiden_res_0.80', 'leiden_res_1.00', 'leiden_res_1.30', 'leiden_res_1.60', 'leiden_res_2.00', 'RNA_snn_res.0.5', 'seurat_clusters', 'palantir_pseudotime'
#     var: 'new_index', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'
#     uns: 'RNA_snn_res.0.5_colors', 'hvg', 'log1p', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap', 'X_xpca_', 'X_xumap_'
#     layers: 'MAGIC_imputed_data', 'counts'
#     obsp: 'connectivities', 'distances'
# AnnData object with n_obs × n_vars = 1721 × 28782
#     obs: 'nCount_RNA', 'nFeature_RNA', 'new_index', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'n_genes', 'doublet_score', 'leiden', 'leiden_res_0.20', 'leiden_res_0.80', 'leiden_res_1.00', 'leiden_res_1.30', 'leiden_res_1.60', 'leiden_res_2.00', 'RNA_snn_res.0.5', 'seurat_clusters', 'palantir_pseudotime'
#     var: 'new_index', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'
#     uns: 'RNA_snn_res.0.5_colors', 'hvg', 'log1p', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap', 'X_xpca_', 'X_xumap_'
#     layers: 'MAGIC_imputed_data', 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata_ref.obs['time'] = adata_ref.obs[pseudotime_key]
adata_query.obs['time'] = adata_query.obs[pseudotime_key]

# %% [markdown]
# ## 1. Preparing data for alignment

# %% [markdown]
# ### Pseudotime range check
# Check whether the current range of pseudotime values are between 0 and 1. If not, run min max normalization.

# %%
t_min, t_max = adata_ref.obs['time'].min(), adata_ref.obs['time'].max()
is_01 = (t_min == 0) and (t_max == 1)
is_01 = np.isclose(t_min, 0) and np.isclose(t_max, 1)
if not is_01:
    print(f"Pseudotime in ref dataset is not in [0, 1] range: min={t_min}, max={t_max}")
    adata_ref.obs['time'] = TimeSeriesPreprocessor.Utils.minmax_normalise(np.asarray(adata_ref.obs['time']))
else:
    print(f"Pseudotime in ref dataset is in [0, 1] range: min={t_min}, max={t_max}")

t_min, t_max = adata_query.obs['time'].min(), adata_query.obs['time'].max()
is_01 = (t_min == 0) and (t_max == 1)
is_01 = np.isclose(t_min, 0) and np.isclose(t_max, 1)
if not is_01:
    print(f"Pseudotime in query dataset is not in [0, 1] range: min={t_min}, max={t_max}")
    adata_query.obs['time'] = TimeSeriesPreprocessor.Utils.minmax_normalise(np.asarray(adata_query.obs['time']))
else:
    print(f"Pseudotime in query dataset is in [0, 1] range: min={t_min}, max={t_max}")

# # uncomment below if the pseudotime range is not [0,1] for any of the objects 
# adata_ref.obs['time'] = TimeSeriesPreprocessor.Utils.minmax_normalise(np.asarray(adata_ref.obs['time']))
# adata_query.obs['time'] = TimeSeriesPreprocessor.Utils.minmax_normalise(np.asarray(adata_query.obs['time']))

print(min(adata_ref.obs['time']), max(adata_ref.obs['time']))
print(min(adata_query.obs['time']), max(adata_query.obs['time']))
# Out:
# 0.0 1.0
# 0.0 1.0

# %%
# Visualize the pseudotime distributions
sb.kdeplot(adata_ref.obs['time'], fill=True, label=f'Reference - {prefix_ref}', color='forestgreen') 
sb.kdeplot(adata_query.obs['time'], fill=True, label=f'Query - {prefix_query}', color='midnightblue'); 
plt.xlabel('pseudotime'); plt.legend()
plt.savefig(f'pseudotime_{prefix_ref}_vs_{prefix_query}.pdf', bbox_inches='tight')
plt.show()
plt.close('all')

# %% [markdown]
# ### Determine the number of discrete pseudotime points to align
#
# We can use optbinning package (https://gnpalencia.org/optbinning/installation.html) to get a heuristic estimate about the number of discrete time points to consider by running below on each dataset.<br>  **Note:** Run `pip install optbinning` if this is not already installed.

# %%
from optbinning import ContinuousOptimalBinning

x = np.asarray(adata_ref.obs.time)
optb = ContinuousOptimalBinning(name='pseudotime', dtype="numerical")
optb.fit(x, x)
print(len(optb.splits))
n_bins = len(optb.splits) # Bins of Reference as a standard

x = np.asarray(adata_query.obs.time)
optb = ContinuousOptimalBinning(name='pseudotime', dtype="numerical")
optb.fit(x, x)
print(len(optb.splits))
# Out:
# (CVXPY) Aug 26 01:34:13 PM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.11.4210). Expected < 9.10.0. Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) Aug 26 01:34:13 PM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.11.4210). Expected < 9.10.0. Please open a feature request on cvxpy to enable support for this version.')
# 15
# 15

# %% [markdown]
# Accordingly, we go with `n_bins=14`

# %% [markdown]
# ### Define which cell type annotations and color scheme to use for visualization purposes
#
# `annotation_colname` and `joint_cmap`

# %%
# # define annotation column name in the adata obs
# annotation_colname = 'leiden_res_0.50' 
# # adata_ref.obs[annotation_colname] = [x.split('_')[1] for x in adata_ref.obs_names] 
# # adata_query.obs[annotation_colname] = [x.split('_')[1] for x in adata_query.obs_names] 

# define the joint colormap to use for both reference and query
joint_order = adata_ref.obs[annotation_colname].unique()
colors = np.array(sb.color_palette('colorblind'))[range(len(joint_order))]
joint_cmap1 = dict(zip(joint_order, colors))

joint_order = adata_query.obs[annotation_colname].unique()
colors = np.array(sb.color_palette('colorblind'))[range(len(joint_order))]
joint_cmap2 = dict(zip(joint_order, colors))

# %% [markdown]
# Inspect the cell type compositions around each discrete pseudotime point (x-axis) to see if it reasonably represents the entire trajectory of interest.

# %%
VisualUtils.plot_pseudotime_dists_with_interpolation_points(adata_ref, adata_query, n_bins)
plt.savefig(f'pseudotime_point_{prefix_ref}_vs_{prefix_query}.pdf', bbox_inches='tight')
plt.show()
plt.close('all')

# %%
VisualUtils.plot_any_legend(joint_cmap1)
plt.savefig(f'pseudotime_{prefix_ref}.pdf', bbox_inches='tight')
plt.show()
plt.close('all')

# %%
plt.close('all')
VisualUtils.plot_any_legend(joint_cmap2)
plt.savefig(f'pseudotime_{prefix_query}.pdf', bbox_inches='tight')
plt.show()
plt.close('all')

# %%
VisualUtils.plot_celltype_barplot(adata_ref, n_bins, annotation_colname, joint_cmap1)
plt.savefig(f'pseudotime_{prefix_ref}_2.pdf', bbox_inches='tight')
plt.show()
plt.close('all')
VisualUtils.plot_celltype_barplot(adata_query, n_bins, annotation_colname, joint_cmap2)
plt.savefig(f'pseudotime_{prefix_query}_2.pdf', bbox_inches='tight')
plt.show()
plt.close('all')

# %% [markdown]
# ## 2. G2G trajectory alignment
#
# **Example gene sets to align:** all human transcription factors, all highly variable genes, lineage-specific genes of interest, a specific pathway gene set etc.

# %%
# define the gene list to align 必须两者都存在的基因
ref_all = adata_ref.var_names
query_all = adata_query.var_names
gene_all = ref_all.intersection(query_all)
if alignment_genes == "hvg":
    print("# Using intersection hvgs...")
    hv_ref   = adata_ref.var_names[adata_ref.var['highly_variable']]
    hv_query = adata_query.var_names[adata_query.var['highly_variable']]
    gene_list = hv_ref.union(hv_query)
    gene_list = gene_list.intersection(gene_all)
else: 
    print("# Using intersection all genes...")
    gene_list = gene_all

print(len(gene_list),'genes')
# Out:
# 6583 genes

# %% [markdown]
# ### Aligning all genes

# %%
aligner = Main.RefQueryAligner(adata_ref, adata_query, gene_list, n_bins) #
aligner.align_all_pairs()
# Out:
# ===============================================================================================================
# Genes2Genes (v0.2.0)
# Dynamic programming alignment of gene pseudotime trajectories using a bayesian information-theoretic framework
# ===============================================================================================================
# Interpolator initialization completed
# Aligner initialised to align trajectories of 537 reference cells & 1721 query cells in terms of 6583 genes
# Running gene-level alignment: 🧬
# 100%|██████████| 6583/6583 [38:05<00:00,  2.88it/s]
# Alignment completed! ✅

# %% [markdown]
# To access gene-level alignments, use the dictionary: `aligner.results_map` which carries all gene alignment objects. <br>
# e.g. `aligner.results_map['TNF']`

# %%
# gene_obj = aligner.results_map['Ga01g00047']
# alignment_str = gene_obj.alignment_str
# print(alignment_str)
# print(VisualUtils.color_al_str(alignment_str)) 
# print()
# print(gene_obj.al_visual)
# # Alignment landscape of costs (Note: dashed black path is the optimal alignment)
# gene_obj.landscape_obj.plot_alignment_landscape()
# # Note: optimal path diagonals represent matches; 
# # vertical and horizontal paths could represent either warp matches or indels (mismatches)

# %% [markdown]
# Visualise alignment in terms of both the cell-type compositions, as well as actual and interpolated gene expression. <br>
# Top left: Visualise alignmebt in terms of cell-type composition <br>
# Bottom left: the mean trends and interpolated distributions of gene expression along pseudotime. <br>
# Bottom right: the actual gene expression values along pseudotime.

# %%
# VisualUtils.plotTimeSeries('Ga01g00047', aligner, plot_cells=True)

# %%
# VisualUtils.show_gene_alignment('TNF', aligner, adata_ref, adata_query, annotation_colname, joint_cmap)

# # Visualise gene-level alignment in terms of only the cell-type composition 
# # VisualUtils.visualize_gene_alignment(aligner.results_map['TNF'], adata_ref, adata_query, annotation_colname, cmap=joint_cmap)

# %% [markdown]
# ### Aggregate (average) cell-level alignment across all aligned genes
#
# This is an average alignment which is sampled based on the frequency distribution of alignment states between each pair of reference and query timepoints. The heatmap value gives the number of genes where the corresponding timepoints have been matched. Note: There can still be different patterns of alignment across these genes (100% mismatching, 100% matching, early mismatching, late mismatching gene groups) which we will find by clustering in the next section.

# %%
aligner.get_aggregate_alignment() 
plt.savefig(f'aggregate_alignment_{prefix_ref}_vs_{prefix_query}.pdf', bbox_inches='tight')
# Note: White path represents the average alignment path where diagonals represent matches; 
# vertical and horizontal paths could represent either warp matches or indels (mismatches)
# Out:
# Average Alignment:  MMMMMMVVVDVVVDVVDVDDDDDD (cell-level)
# % similarity: 62.5

# %%
plt.close('all')

# %% [markdown]
# ## 3. Analysing gene-level alignments
#
# Ranking genes based on their alignment similarities

# %%
df = aligner.get_stat_df() # ordered genes according to alignment similarity statistics 
plt.savefig(f'ranking_genes_{prefix_ref}_vs_{prefix_query}.pdf', bbox_inches='tight')
# Out:
# Mean alignment similarity percentage (matched %):
# 60.519999999999996 %

# %%
plt.close('all')

# %%
print(df)
print('Ten genes of the lowest similarity: ')
print(df['Gene'][1:10])
df.to_csv(f"ranking_genes__{prefix_ref}_vs_{prefix_query}.csv", index=False)
# Out:
#             Gene alignment_similarity_percentage opt_alignment_cost l2fc  \
# 430   Ga01g02511                             0.0          76.678455 -inf
# 658   Ga14g01058                             0.0          76.678455 -inf
# 1137  Ga03g00652                             0.0          76.678455 -inf
# 1173  Ga03g00447                             0.0          76.678455 -inf
# 1281  Ga04g01820                             0.0          76.678455 -inf
# ...          ...                             ...                ...  ...
# 5473  Ga12g01637                             1.0          -1.370787  NaN
# 5600  Ga12g00977                             1.0          -1.370787  NaN
# 5783  Ga05g00518                             1.0          -1.370787  NaN
# 6330  Ga13g01221                             1.0          -1.370787  NaN
# 6387  Ga13g01555                             1.0          -1.370787  NaN
#
#       color abs_l2fc
# 430     red      inf
# 658     red      inf
# 1137    red      inf
# 1173    red      inf
# 1281    red      inf
# ...     ...      ...
# 5473  green      NaN
# 5600  green      NaN
# 5783  green      NaN
# 6330  green      NaN
# 6387  green      NaN
#
# [6583 rows x 6 columns]
# Ten genes of the lowest similarity:
# 658     Ga14g01058
# 1137    Ga03g00652
# 1173    Ga03g00447
# 1281    Ga04g01820
# 1356    Ga04g01317
# 1422    Ga12g01951
# 1473    Ga04g00697
# 1691    Ga05g02172
# 1754    Ga05g02544
# Name: Gene, dtype: object

# %%
VisualUtils.plot_alignmentSim_vs_l2fc(df)
plt.savefig(f'ranking_genes_log2_{prefix_ref}_vs_{prefix_query}.pdf', bbox_inches='tight')

# %%
plt.close('all')

# %% [markdown]
# A ranked list of genes based on their first match occurrence

# %%
earliest_match_sorted_genes_list = aligner.show_ordered_alignments()
# Out:
# In the order of the first match occurrence along pseudotime
# Gene        Alignment
# ----------  ------------------------------
# Ga01g00129  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g00047  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g00095  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g00162  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g00241  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g00298  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g00337  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g00628  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g00729  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g00776  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g00942  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01059  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01114  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01116  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01117  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01122  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01207  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01480  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00973  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00971  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g01053  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00871  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00917  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00938  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00803  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g01099  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g01221  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g01256  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g01385  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g01530  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g01590  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g01545  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g01592  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g00496  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g01907  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02511  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02470  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02526  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02308  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02199  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02155  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02163  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02063  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02059  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02056  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02031  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02019  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02099  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01999  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01908  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01781  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01780  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01570  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01540  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00729  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00695  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00727  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00604  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g01058  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g00358  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g01543  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g01798  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g01535  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00529  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00471  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00422  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00339  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00311  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00261  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00221  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00158  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g00012  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g01763  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02476  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02418  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02361  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02378  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02318  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02291  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02270  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02217  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02164  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02071  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02079  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g02039  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01966  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01958  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01869  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01803  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01769  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01765  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01757  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01707  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01660  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01652  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01565  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01523  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01476  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01454  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01309  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01278  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01266  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01028  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01125  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g01081  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g01070  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00883  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00888  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00865  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00797  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00717  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00690  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00652  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00635  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00584  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00547  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00507  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00447  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00446  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00352  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00300  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00206  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00239  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00087  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00083  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga03g00030  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01820  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01819  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01755  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01658  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01621  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01513  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01409  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01356  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01329  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01317  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01307  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01280  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01189  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01177  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01002  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00960  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01951  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00865  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00920  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01018  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g01017  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00697  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00613  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00485  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00478  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00456  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00159  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00244  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00329  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00311  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00267  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00261  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00236  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga04g00044  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g00278  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00013  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00069  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00047  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00087  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00129  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00181  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00207  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00582  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02183  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02172  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02337  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02338  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02370  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02539  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02544  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02585  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02613  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01206  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02670  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02671  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02718  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02724  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02774  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02921  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g03176  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g03239  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g03221  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g03390  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g03414  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g03468  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g03384  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g03674  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g03629  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g03881  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g04002  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g04015  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00025  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00108  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00211  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g00621  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00318  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00393  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00428  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00501  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00524  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00587  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00677  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00691  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00758  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00874  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00884  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00943  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g00972  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01002  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01261  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01341  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01217  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01427  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01462  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01738  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g01567  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01568  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01596  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01623  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01640  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01670  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01758  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g01932  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g02209  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g02176  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g02106  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga06g02084  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00065  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00049  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00112  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00124  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00162  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00149  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00191  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00190  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00214  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00268  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00381  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00439  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00481  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00524  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00569  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00578  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00599  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00729  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00809  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00820  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g00821  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g00741  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01018  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01008  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01045  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01136  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01145  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01160  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01252  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01270  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01338  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g00037  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01407  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01410  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01450  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01446  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01434  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01556  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01643  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01624  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01623  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01600  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01714  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01698  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g01883  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01788  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01807  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01800  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01832  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01888  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g01975  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02076  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02152  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02166  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02200  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02231  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02270  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02288  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02333  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02351  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02374  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02449  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga07g02466  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00097  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00080  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00145  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00264  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00292  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g01642  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga02g01607  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00353  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00356  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00436  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00465  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00575  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00632  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00722  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00745  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00755  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00840  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00856  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g00910  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g00246  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01178  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01137  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01326  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01515  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01555  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01595  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01625  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01680  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01899  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01910  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01926  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01929  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01948  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01970  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g01987  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g02064  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g02083  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g02111  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g02135  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g02223  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g02401  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g02529  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g02541  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g02594  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga08g02700  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g00079  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g00551  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g00447  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g01638  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g00645  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g00834  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g00861  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g00900  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g00915  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g00967  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g00986  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00048  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01018  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01104  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01205  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01268  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01339  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01351  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01353  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01382  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01619  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01636  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01820  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01845  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01676  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01714  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01740  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01984  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g01999  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g02053  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g02208  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g02534  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga09g02419  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02684  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02530  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02532  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02499  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02446  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02369  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02349  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02240  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02465  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02183  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02177  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02150  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02134  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02130  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g02097  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01765  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01806  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01820  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01653  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01607  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01606  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01602  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01583  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01511  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01500  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01466  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01353  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01241  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01062  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g00795  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g00626  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g00551  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g00531  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g00501  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g00450  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g00371  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g00242  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g00026  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g00061  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g00065  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03764  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03736  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03680  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03679  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03658  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03657  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03640  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03511  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03345  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03299  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03262  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03172  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03130  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03075  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03011  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02983  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02933  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02856  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02736  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02737  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02713  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02671  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02594  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02549  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02421  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02393  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02262  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02171  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02129  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g02108  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01935  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01911  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01830  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01819  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01726  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01703  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01603  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01672  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01569  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01340  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01434  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01388  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01375  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01444  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g01272  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g00654  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00811  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00755  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00442  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00341  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00322  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00294  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00232  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00168  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00178  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00139  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00115  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g00102  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00012  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00095  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00091  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00120  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00165  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00198  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00233  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00232  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00270  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00340  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00363  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00397  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00456  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00504  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00522  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00550  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00671  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00665  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00678  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00708  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00716  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00721  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00759  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00778  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00796  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00832  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g00119  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02561  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g00202  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02464  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02450  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02447  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02334  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga10g01867  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02222  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02146  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02152  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02031  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02190  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g01494  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01947  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01908  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01896  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01883  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01639  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01589  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01544  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01540  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01515  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01479  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01420  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01431  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01400  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01324  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01305  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01163  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g01133  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00995  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g00985  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga14g00091  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02609  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga12g02682  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga11g03789  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00009  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00012  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00042  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00053  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00074  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00113  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00159  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00230  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00254  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00344  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00363  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00412  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00459  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00427  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00468  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00543  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00537  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00681  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00654  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00717  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00733  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00741  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00783  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00829  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00798  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00811  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00857  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00885  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g00904  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01024  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01037  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01119  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01154  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01200  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01246  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01238  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01281  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01354  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01409  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01463  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01537  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01531  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01586  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01729  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01780  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01797  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01879  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01880  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01881  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01918  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01923  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01926  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01974  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g01976  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02078  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02129  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02155  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02217  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga05g02193  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00393  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00405  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00463  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00313  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00684  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00697  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00727  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00775  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00826  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00849  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00854  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00896  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g01019  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g00915  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g01111  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g01267  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g01522  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g01576  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g01580  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g01661  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g01836  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g01882  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g01949  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g01963  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02008  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02080  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02127  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02171  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02241  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02260  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02262  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02289  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02297  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02324  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02330  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02406  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga13g02474  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# Ga01g02207  MMVVVVVVVVVMMMMWWWWWWWWW
# Ga05g02045  MMMVVVVVVVVMMMMWWWWWWWW
# Ga12g00178  MVVVVVVMMMMMMWWWWWWWWII
# Ga01g02100  MMMMVVVVMMMMMMMWWWW
# Ga09g01585  MMMMVVVVMMMMMMMWWWW
# Ga01g00030  MMMMMMMMMMMMMMM
# Ga01g00065  MMMMMMMMMMMMWWWIII
# Ga01g00066  MMMMMMMMMMMMMMM
# Ga01g00084  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g00085  MMMMMMMMMMMMMMM
# Ga01g00108  MMMMMMMMMMMMMMM
# Ga01g00111  MMMMMMMMMMMMMMM
# Ga01g00114  MMMMMMMMMMMMMMM
# Ga01g00176  MMMMMMMMMMMMMMM
# Ga01g00177  MMMMMMMMMMMMMMM
# Ga01g00193  MMMMMMMMMMMMMMM
# Ga01g00220  MMMMMMMMMMMMMMM
# Ga01g00286  MMMMMMMMMMMMMMM
# Ga01g00267  MMMMMMMMWWWWWWWIIIIIII
# Ga01g00274  MMMMMMMMMMMMMMM
# Ga01g00295  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga01g00328  MMMMMMMMMMMMMMM
# Ga01g00343  MMMMMMMMMMMMMMM
# Ga01g00345  MMMMMMMMMMMMMMM
# Ga01g00362  MMMMMMMMMMMMMMM
# Ga01g00409  MMMMMMMMMMMMMMM
# Ga01g00440  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g00456  MMMMMMMMWWWWWWWIIIIIII
# Ga01g00522  MMMMMMMMMMMMMMM
# Ga01g00601  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g00610  MMMMMMMMMMMMMMM
# Ga01g00617  MMMMMMMMMMMMMMM
# Ga01g00630  MMMMMMMMMMMMMMM
# Ga01g00641  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g00642  MMMMMMMMMMMMMMM
# Ga01g00655  MMMMMMMMMMMMMMM
# Ga01g00681  MMMMMMMMWWWWWWWIIIIIII
# Ga01g00674  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g00685  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g00684  MMMMMMMMMMMMMMM
# Ga01g00686  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g00711  MMMMMMMMMMMMMMM
# Ga01g00739  MMMMMMMMMMMMMMM
# Ga01g00747  MMMMMMWWWWWWWWWIIIIIIIII
# Ga13g01007  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g00759  MMMMMMMMMMMMMMM
# Ga01g00779  MMMMMMMMMMMMMMM
# Ga01g00775  MMMMMMMMMMMMMMM
# Ga01g00784  MMMMMMMMWWWWWWWIIIIIII
# Ga01g00788  MMMMMMMMMMMMWWWIII
# Ga01g00786  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g00803  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g00844  MMMMMMMMMMMMMMM
# Ga01g00852  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g00858  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga01g00879  MMMMMMMMMMMMMMM
# Ga01g00902  MMMMMMMMMMMMMMM
# Ga01g00903  MMMMMMMMMWWWWWWIIIIII
# Ga01g00922  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga01g00945  MMMMMMMMMMMWWWWIIII
# Ga04g01386  MMMMMMMMWWWWWWWIIIIIII
# Ga01g01016  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g01017  MMMMMMMMMMMMMMM
# Ga01g01034  MMMMMMMMMMMMMMM
# Ga01g01054  MMMMMMMMMMMMMMM
# Ga01g01099  MMMMMMMMMMMMMMM
# Ga01g01131  MMMMMMMMMMMMMMM
# Ga14g01880  MMMMMMMMMMMMMMM
# Ga01g01334  MMMMMMMMMMMMMMM
# Ga01g01322  MMMMMMMMMMMMMMM
# Ga01g01320  MMMMMMMMMMMMMMM
# Ga01g01399  MMMMMMMMMMMMWWWIII
# Ga01g01412  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g01408  MMMMMMMMMMMMMMM
# Ga14g00592  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g01470  MMMMMMMMMMMMMMM
# Ga02g00719  MMMMMMMMMMMMMMM
# Ga01g01383  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g01394  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g01373  MMMMMMMMMMMMMMM
# Ga01g01374  MMMMMMMMMMMMMMM
# Ga01g01464  MMMMMMMMMMMMMMM
# Ga01g01171  MMMMMMMMMMMMMMM
# Ga08g01904  MMMMMMMMMMMMMMM
# Ga01g01180  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g01232  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g01497  MMMMMMMMMWWWWWWIIIIII
# Ga01g01483  MMMMMMMMMMMMMMM
# Ga14g00811  MMMMMMMMMMMMMMM
# Ga14g00728  MMMMMMMMMMMMMMM
# Ga01g01294  MMMMMMMMMMMMMMM
# Ga01g01274  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g01276  MMMMMMMMMMMMMMM
# Ga01g01258  MMMMMMMMWWWWWWWIIIIIII
# Ga01g01500  MMMMMMMMMMMMMMM
# Ga01g01495  MMMMMMMMMMMMMMM
# Ga14g01661  MMMMMMMMWWWWWWWIIIIIII
# Ga02g00892  MMMMMMMMMMMMMMM
# Ga02g00853  MMMMMMMMMMMMMMM
# Ga02g00857  MMMMMMMMMMMMMMM
# Ga02g00863  MMMMMMMMMMMMMMM
# Ga08g00615  MMMMMMMMWWWWWWWIIIIIII
# Ga02g00994  MMMMMMMMMMMMMMM
# Ga04g00777  MMMMMMWWWWWWWWWIIIIIIIII
# Ga02g01055  MMMMMMMMMMMMMMM
# Ga02g01039  MMMMMMMMMMMMMMM
# Ga02g01027  MMMMMMMMMMMMMMM
# Ga02g00872  MMMMMMMMMMMMMMM
# Ga02g00877  MMMMMMMMMMMMMMM
# Ga02g00882  MMMMMMMMMMMMMMM
# Ga02g00884  MMMMMMMMWWWWWWWIIIIIII
# Ga02g00940  MMMMMMMMMMMMMMM
# Ga02g00943  MMMMMMMWWWWWWWWIIIIIIII
# Ga02g00929  MMMMMMMWWWWWWWWIIIIIIII
# Ga02g00928  MMMMMMMMMMMMMMM
# Ga02g00925  MMMMMMMMMMMMMMM
# Ga02g00796  MMMMMMMMMMMMMMM
# Ga02g00795  MMMMMMMMMMMMMMM
# Ga02g00800  MMMMMMMMMMMMMMM
# Ga02g00802  MMMMMMMMMMMMMMM
# Ga02g00825  MMMMMMMMMMMMMMM
# Ga02g00831  MMMMMMMMMMMMMMM
# Ga02g01067  MMMMMMMMMMMMMMM
# Ga02g01089  MMMMMMMMMMMMMMM
# Ga02g01097  MMMMMMWWWWWWWWWIIIIIIIII
# Ga02g01092  MMMMMMMMMMMMMMM
# Ga02g01159  MMMMMMMMMMMMMMM
# Ga02g01198  MMMMMMMMMMMMMMM
# Ga02g01199  MMMMMMMMMMMMMMM
# Ga02g01205  MMMMMMMMMMMMMMM
# Ga02g01224  MMMMMMMMMMMMMMM
# Ga02g01236  MMMMMMMMMMMMMMM
# Ga02g01255  MMMMMMMWWWWWWWWIIIIIIII
# Ga02g01252  MMMMMMMMWWWWWWWIIIIIII
# Ga02g01299  MMMMMMMMMMMMMMM
# Ga02g01303  MMMMMMMMMMMMMMM
# Ga02g01309  MMMMMMMMMMMMMMM
# Ga02g01308  MMMMMMMMMMMMMMM
# Ga02g01327  MMMMMMWWWWWWWWWIIIIIIIII
# Ga02g01322  MMMMMMMMMMMMMMM
# Ga02g01323  MMMMMMMMMMMMMMM
# Ga02g01367  MMMMMMMMMMMMMMM
# Ga02g01368  MMMMMMMMMMMMMMM
# Ga02g01387  MMMMMMMMMMMMMMM
# Ga02g01390  MMMMMMMMMMMMMMM
# Ga02g01398  MMMMMMMMMMMMMMM
# Ga02g01411  MMMMMMMMMMMMMMM
# Ga02g01415  MMMMMMMMMMMMMMM
# Ga02g01418  MMMMMMMWWWWWWWWIIIIIIII
# Ga02g01470  MMMMMMMMMMMMMMM
# Ga02g01472  MMMMMMMMMMMWWWWIIII
# Ga02g01489  MMMMMMMMMMMMMMM
# Ga02g01522  MMMMMMMMMMMMMMM
# Ga02g01535  MMMMMMMWWWWWWWWIIIIIIII
# Ga02g01534  MMMMMMMMWWWWWWWIIIIIII
# Ga02g01548  MMMMMMMMMMMMMMM
# Ga02g01563  MMMMMMMMMMMMMMM
# Ga02g01572  MMMMMMMMMMMMMMM
# Ga02g01603  MMMMMMMMMMMMMMM
# Ga14g00494  MMMMMMMMMMMMMMM
# Ga14g00447  MMMMMMMMMMMMMMM
# Ga14g00473  MMMMMMMMMMMMMMM
# Ga14g00462  MMMMMMMMMMMMMMM
# Ga14g00456  MMMMMMMMMMMMMMM
# Ga14g00435  MMMMMMMMMMMMMMM
# Ga01g02502  MMMMMMMMMMMMMMM
# Ga01g02499  MMMMMMMMMMMMMMM
# Ga01g02479  MMMMMMMMMMMMMMM
# Ga01g02469  MMMMMMMMMMMMMMM
# Ga01g02454  MMMMMMMMWWWWWWWIIIIIII
# Ga12g02271  MMMMMMMMMMMMMMM
# Ga01g02557  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g02558  MMMMMMMMMMMMMMM
# Ga01g02534  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga01g02532  MMMMMMMMMMMMMMM
# Ga01g02529  MMMMMMMMMMMMMMM
# Ga01g02415  MMMMMMMMMMMMMMM
# Ga01g02423  MMMMMMMMMMMMMMM
# Ga01g02428  MMMMMMMMMMMMMMM
# Ga01g02391  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g02387  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g02369  MMMMMMMMMMMMMMM
# Ga01g02368  MMMMMMMMMMMMMMM
# Ga01g02360  MMMMMMMMMMMMMMM
# Ga01g02279  MMMMMMMMMMMMMMM
# Ga01g02293  MMMMMMMMMMMMMMM
# Ga01g02328  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga01g02315  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga01g02312  MMMMMMMMMMMMMMM
# Ga01g02334  MMMMMMMMMMMMMMM
# Ga01g02317  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g02319  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g02349  MMMMMMMMMMMMMMM
# Ga01g02215  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g02244  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g02245  MMMMMMMMMMMMMMM
# Ga01g02252  MMMMMMMMMMMMMMM
# Ga01g02259  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g02269  MMMMMMMMMMWWWWWIIIII
# Ga01g02266  MMMMMMMMMMMMMMM
# Ga01g02188  MMMMMMMMMMMMMMM
# Ga01g02160  MMMMMMMMMMMMMMM
# Ga01g02125  MMMMMMMMMMMMMMM
# Ga01g02042  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g02028  MMMMMMMMMMMMMMM
# Ga01g02018  MMMMMMMMMMMMMMM
# Ga01g02089  MMMMMMMMMMMMMMM
# Ga01g02083  MMMMMMMMMMMMMMM
# Ga01g01990  MMMMMMMMMMMMMMM
# Ga01g01991  MMMMMMMMMWWWWWWIIIIII
# Ga01g01950  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g01973  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g01976  MMMMMMMMMMMMMMM
# Ga01g01920  MMMMMMMMMMMMMMM
# Ga01g01926  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g01867  MMMMMMMMMMMMMMM
# Ga01g01861  MMMMMMMMMMMMMMM
# Ga01g01844  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g01808  MMMMMMMMWWWWWWWIIIIIII
# Ga01g01795  MMMMMMMMMMMMMMM
# Ga01g01664  MMMMMMMMMMWWWWWIIIII
# Ga01g01730  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g01731  MMMMMMMMMMMMMMM
# Ga01g01735  MMMMMMWWWWWWWWWIIIIIIIII
# Ga01g01744  MMMMMMMMMMMMMMM
# Ga01g01660  MMMMMMMMMMMMMMM
# Ga01g01680  MMMMMMMMMMMMMMM
# Ga02g00701  MMMMMMMMMMMMMMM
# Ga01g01524  MMMMMMMWWWWWWWWIIIIIIII
# Ga01g01583  MMMMMMMMMMMMMMM
# Ga01g01589  MMMMMMMMMMMMMMM
# Ga01g01591  MMMMMMMMMWWWWWWIIIIII
# Ga01g01592  MMMMMMMMMMMMMMM
# Ga01g01612  MMMMMMMMMMMMMMM
# Ga01g01633  MMMMMMMMMMMMMMM
# Ga01g01534  MMMMMMMMMMMMMMM
# Ga02g00694  MMMMMMMMMMMMMMM
# Ga14g01133  MMMMMMWWWWWWWWWIIIIIIIII
# Ga02g00764  MMMMMMMMMMMMMMM
# Ga02g00773  MMMMMMMMMMMMMMM
# Ga02g00769  MMMMMMMMMMMMMMM
# Ga02g00781  MMMMMMMMMMMMMMM
# Ga02g00574  MMMMMMMMWWWWWWWIIIIIII
# Ga02g00631  MMMMMMMMMMMMWWWIII
# Ga02g00635  MMMMMMMWWWWWWWWIIIIIIII
# Ga02g00643  MMMMMMMMMMMMMMM
# Ga02g00660  MMMMMMMWWWWWWWWIIIIIIII
# Ga02g00540  MMMMMMMMMMMMMMM
# Ga02g00538  MMMMMMMMMMMMMMM
# Ga02g00515  MMMMMMMMMMMMMMM
# Ga02g00454  MMMMMMMMMMMMMMM
# Ga02g00429  MMMMMMMMMMMMMMM
# Ga02g00430  MMMMMMMMWWWWWWWIIIIIII
# Ga02g00395  MMMMMMMMMMMMMMM
# Ga02g00400  MMMMMMMMMMMMMMM
# Ga02g00401  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga02g00402  MMMMMMMMMMMMMMM
# Ga02g00388  MMMMMMMMMMMMMMM
# Ga14g01266  MMMMMMMMMMMMMMM
# Ga02g00386  MMMMMMMMMMMMMMM
# Ga02g00376  MMMMMMMMWWWWWWWIIIIIII
# Ga02g00371  MMMMMMMMMMMMMMM
# Ga02g00349  MMMMMMMMWWWWWWWIIIIIII
# Ga02g00334  MMMMMMMMMMMMMMM
# Ga02g00330  MMMMMMMMMMMMMMM
# Ga02g00305  MMMMMMMMMMMMMMM
# Ga02g00301  MMMMMMMMMMMMMMM
# Ga02g00292  MMMMMMMMMMMMMMM
# Ga02g00275  MMMMMMMMMMMMMMM
# Ga02g00279  MMMMMMMMMMMMMMM
# Ga02g00276  MMMMMMMMMMMMMMM
# Ga02g00232  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga02g00215  MMMMMMMMWWWWWWWIIIIIII
# Ga02g00211  MMMMMMMMMMMMMMM
# Ga02g00203  MMMMMMMMMMMMMMM
# Ga02g00191  MMMMMMMMMMMMMMM
# Ga02g00185  MMMMMMMWWWWWWWWIIIIIIII
# Ga02g00162  MMMMMMWWWWWWWWWIIIIIIIII
# Ga02g00124  MMMMMMMMMMMMMMM
# Ga02g00129  MMMMMMMMMMMMMMM
# Ga02g00128  MMMMMMMMMMMMMMM
# Ga02g00118  MMMMMMMMMMMMMMM
# Ga02g00117  MMMMMMMMMMMMMMM
# Ga02g00087  MMMMMMMWWWWWWWWIIIIIIII
# Ga02g00106  MMMMMMWWWWWWWWWIIIIIIIII
# Ga02g00103  MMMMMMMMWWWWWWWIIIIIII
# Ga02g00049  MMMMMMWWWWWWWWWIIIIIIIII
# Ga02g00035  MMMMMMMMMMMMMMM
# Ga02g00028  MMMMMMMMMMMMMMM
# Ga02g00020  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g02507  MMMMMMMMWWWWWWWIIIIIII
# Ga03g02501  MMMMMMMMMMWWWWWIIIII
# Ga03g02479  MMMMMMMMMMMMMMM
# Ga03g02461  MMMMMMMMMMMMMMM
# Ga03g02454  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g02425  MMMMMMMMMMMMMMM
# Ga03g02395  MMMMMMMMMMMMMMM
# Ga03g02372  MMMMMMMMMMMMMMM
# Ga03g02362  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g02324  MMMMMMMMMMMMMMM
# Ga03g02309  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g02269  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga03g02266  MMMMMMMMMMWWWWWIIIII
# Ga03g02241  MMMMMMMMMMMMMMM
# Ga03g02231  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g02222  MMMMMMMMMMMMMMM
# Ga03g02209  MMMMMMMMMMMMMMM
# Ga03g02186  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g02181  MMMMMMMMMMMMMMM
# Ga03g02161  MMMMMMMMMMMMMMM
# Ga03g02162  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g02160  MMMMMMMMMMMMMMM
# Ga03g02133  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g02092  MMMMMMMMMMMMMMM
# Ga03g02066  MMMMMMMMMMMMMMM
# Ga03g02048  MMMMMMMMMMMMMMM
# Ga03g02047  MMMMMMMMMMMMMMM
# Ga03g02046  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g02038  MMMMMMMMMMMMMMM
# Ga03g02017  MMMMMMMMMMMMMMM
# Ga03g02007  MMMMMMMMMMMMMMM
# Ga03g01998  MMMMMMMMMMMMMMM
# Ga03g01979  MMMMMMMMMMMMMMM
# Ga03g01978  MMMMMMMMMMMMMMM
# Ga03g01960  MMMMMMMMMMMMMMM
# Ga03g01950  MMMMMMMMMMMMMMM
# Ga03g01934  MMMMMMMMMMMMMMM
# Ga03g01914  MMMMMMMMWWWWWWWIIIIIII
# Ga03g01908  MMMMMMMMMMMMMMM
# Ga03g01902  MMMMMMMMMMMMMMM
# Ga03g01900  MMMMMMMMMMMMMMM
# Ga03g01877  MMMMMMMMMMMMMMM
# Ga03g01873  MMMMMMMMMMMMMMM
# Ga03g01866  MMMMMMMMMMMMMMM
# Ga03g01859  MMMMMMMMMMMMMMM
# Ga03g01848  MMMMMMMMMMMMMMM
# Ga03g01832  MMMMMMMMMMMMMMM
# Ga03g01824  MMMMMMMMMMMMMMM
# Ga03g01798  MMMMMMMMMMMMMMM
# Ga03g01782  MMMMMMMMMMMMMMM
# Ga03g01783  MMMMMMMMMMMMMMM
# Ga03g01774  MMMMMMMMMMMMMMM
# Ga03g01768  MMMMMMMMMMMMMMM
# Ga03g01761  MMMMMMMMMMMMMMM
# Ga03g01756  MMMMMMMMMMMMMMM
# Ga03g01734  MMMMMMMMMMMMMMM
# Ga03g01729  MMMMMMMMMMMMMMM
# Ga03g01700  MMMMMMMMMMMMMMM
# Ga03g01691  MMMMMMMMMMMMMMM
# Ga03g01685  MMMMMMMMMMMMMMM
# Ga03g01632  MMMMMMMMWWWWWWWIIIIIII
# Ga03g01640  MMMMMMMMMMMMMMM
# Ga03g01621  MMMMMMMMMMMMMMM
# Ga03g01619  MMMMMMMMMMMMMMM
# Ga03g01571  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga03g01564  MMMMMMMMMMMMMMM
# Ga03g01555  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g01551  MMMMMMMMMMMMMMM
# Ga03g01550  MMMMMMMMMMMMMMM
# Ga03g01543  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g01524  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g01521  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g01518  MMMMMMMMMMMMMMM
# Ga03g01514  MMMMMMMMMMMMMMM
# Ga03g01502  MMMMMMMMMMMMMMM
# Ga03g01496  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g01469  MMMMMMMMMMMMMMM
# Ga06g01744  MMMMMMMMMMMMMMM
# Ga03g01439  MMMMMMMMMMMMMMM
# Ga03g01431  MMMMMMMMMMMMMMM
# Ga03g01417  MMMMMMMMMMMMMMM
# Ga03g01414  MMMMMMMMMMMMMMM
# Ga03g01392  MMMMMMMMWWWWWWWIIIIIII
# Ga03g01386  MMMMMMMMMMMMMMM
# Ga03g01372  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g01367  MMMMMMMMMMMMMMM
# Ga03g01366  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g01359  MMMMMMMMMMMMMMM
# Ga03g01355  MMMMMMMMMMMMMMM
# Ga03g01353  MMMMMMMMMMMMMMM
# Ga03g01345  MMMMMMMMMMMMMMM
# Ga03g01279  MMMMMMMMMMMMMMM
# Ga03g01282  MMMMMMMMMMMMMMM
# Ga03g01295  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g01303  MMMMMMMMMMMMMMM
# Ga03g01305  MMMMMMMMMMMMMMM
# Ga03g01263  MMMMMMMMMMMMMMM
# Ga03g01212  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g01051  MMMMMMMMMMMMMMM
# Ga03g01048  MMMMMMMMMMMMMMM
# Ga03g01082  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga03g01083  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga01g01775  MMMMMMMMMMMMMMM
# Ga05g03474  MMMMMMMMMMMMMMM
# Ga03g01191  MMMMMMMMMMMMMMM
# Ga03g00925  MMMMMMMMMMMMMMM
# Ga03g01225  MMMMMMMMMMMMMMM
# Ga03g01221  MMMMMMMMMMMMMMM
# Ga03g00875  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g00891  MMMMMMMMWWWWWWWIIIIIII
# Ga03g00900  MMMMMMMMMMMMMMM
# Ga14g00530  MMMMMMMMMMMMMMM
# Ga14g00534  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g00839  MMMMMMMMMMMMMMM
# Ga03g00841  MMMMMMMMMMMMMMM
# Ga03g00829  MMMMMMMMMMMMMMM
# Ga03g00823  MMMMMMMMMMMMMMM
# Ga03g00812  MMMMMMMMMMMMMMM
# Ga05g03462  MMMMMMMMMMMMMMM
# Ga03g00765  MMMMMMMMMMMMMMM
# Ga03g00756  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g00722  MMMMMMMMMMMMMMM
# Ga03g00720  MMMMMMMMMMMMMMM
# Ga03g00694  MMMMMMMMMMMMMMM
# Ga03g00681  MMMMMMMMMWWWWWWIIIIII
# Ga03g00680  MMMMMMMMMMMMMMM
# Ga03g00661  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga03g00628  MMMMMMMMMMMMMMM
# Ga03g00624  MMMMMMMMMMMMMMM
# Ga03g00602  MMMMMMMMMMMMMMM
# Ga03g00593  MMMMMMMWWWWWWWWIIIIIIII
# Ga10g00327  MMMMMMMMWWWWWWWIIIIIII
# Ga03g00545  MMMMMMMMWWWWWWWIIIIIII
# Ga03g00541  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g00522  MMMMMMMMMWWWWWWIIIIII
# Ga03g00519  MMMMMMMMMMMMMMM
# Ga03g00511  MMMMMMMMMMMMWWWIII
# Ga03g00502  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g00561  MMMMMMMMMMMMMMM
# Ga03g00478  MMMMMMMMMMMMMMM
# Ga03g00450  MMMMMMMMMMMMMMM
# Ga03g00445  MMMMMMMMMMMMMMM
# Ga03g00443  MMMMMMMMMMMMMMM
# Ga03g00420  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g00415  MMMMMMMMMMMMMMM
# Ga03g00411  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g00406  MMMMMMMMWWWWWWWIIIIIII
# Ga03g00378  MMMMMMMWWWWWWWWIIIIIIII
# Ga03g00390  MMMMMMMMMMMMMMM
# Ga03g00391  MMMMMMMMMMMMMMM
# Ga03g00366  MMMMMMMMMMMMMMM
# Ga03g00307  MMMMMMMMMMMMMMM
# Ga03g00298  MMMMMMMMMMMMMMM
# Ga03g00287  MMMMMMMMMMMMMMM
# Ga03g00272  MMMMMMMMMMMMMMM
# Ga03g00265  MMMMMMWWWWWWWWWIIIIIIIII
# Ga04g01257  MMMMMMMMMMMMMMM
# Ga03g00238  MMMMMMMMMMMMMMM
# Ga03g00196  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga03g00183  MMMMMMMMMMMMMMM
# Ga03g00182  MMMMMMMMMMMMMMM
# Ga03g00177  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g00156  MMMMMMMMMMMMMMM
# Ga03g00129  MMMMMMWWWWWWWWWIIIIIIIII
# Ga03g00126  MMMMMMMMMMMMMMM
# Ga03g00119  MMMMMMMMMMMMMMM
# Ga03g00124  MMMMMMMMMMMMMMM
# Ga03g00085  MMMMMMMMMMMMMMM
# Ga03g00048  MMMMMMMMMMMMMMM
# Ga03g00039  MMMMMMMMMMMMMMM
# Ga03g00036  MMMMMMMMMMMMMMM
# Ga03g00023  MMMMMMMMMMMMMMM
# Ga03g00022  MMMMMMMMMMMMMMM
# Ga04g01910  MMMMMMMMMMMMMMM
# Ga04g01897  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g01900  MMMMMMMMMMMMMMM
# Ga04g01895  MMMMMMMMMMMMMMM
# Ga04g01893  MMMMMMMMWWWWWWWIIIIIII
# Ga04g01866  MMMMMMMMWWWWWWWIIIIIII
# Ga04g01879  MMMMMMMMMMMMMMM
# Ga04g01846  MMMMMMWWWWWWWWWIIIIIIIII
# Ga04g01838  MMMMMMMMMMMMMMM
# Ga04g01836  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g01835  MMMMMMMMMMMMMMM
# Ga04g01826  MMMMMMMMMMMMMMM
# Ga08g01078  MMMMMMMMMMMMMMM
# Ga04g01765  MMMMMMMMMMMMMMM
# Ga04g01750  MMMMMMMMMMMMMMM
# Ga04g01709  MMMMMMMMMMMMMMM
# Ga04g01697  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g01685  MMMMMMMMMMMMMMM
# Ga04g01681  MMMMMMMMMMMMMMM
# Ga04g01598  MMMMMMMMMMMMMMM
# Ga10g00828  MMMMMMMMMMMMMMM
# Ga04g01516  MMMMMMWWWWWWWWWIIIIIIIII
# Ga04g01512  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g01505  MMMMMMMMMMMMMMM
# Ga04g01486  MMMMMMMMMMMMMMM
# Ga04g01471  MMMMMMMMMMMMMMM
# Ga04g01465  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga04g01450  MMMMMMMMMMMMMMM
# Ga04g01444  MMMMMMMWWWWWWWWIIIIIIII
# Ga13g02311  MMMMMMMMMMMMMMM
# Ga04g01426  MMMMMMWWWWWWWWWIIIIIIIII
# Ga04g01422  MMMMMMMMMMMMMMM
# Ga04g01408  MMMMMMMMMMMMMMM
# Ga04g01371  MMMMMMMMMMMMMMM
# Ga04g01357  MMMMMMMMMMMMMMM
# Ga04g01358  MMMMMMMMMMMMMMM
# Ga04g01352  MMMMMMMMWWWWWWWIIIIIII
# Ga04g01350  MMMMMMMMMMMMMMM
# Ga04g01347  MMMMMMMMMMMMMMM
# Ga04g01332  MMMMMMMMMMMMMMM
# Ga04g01279  MMMMWWWWWWWWWWWIIIIIIIIIII
# Ga04g01260  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g01254  MMMMMMMMMMMMWWWIII
# Ga04g01225  MMMMMMMMMMMMMMM
# Ga04g01199  MMMMMMMMMMMMMMM
# Ga14g00563  MMMMMMMMMMMMMMM
# Ga04g01188  MMMMMMMMMMMMWWWIII
# Ga04g01186  MMMMMMMMWWWWWWWIIIIIII
# Ga14g00893  MMMMMMMMWWWWWWWIIIIIII
# Ga14g00897  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g01064  MMMMMMMMMMMMMMM
# Ga04g01106  MMMMMMMMMMMMMMM
# Ga04g01155  MMMMMMWWWWWWWWWIIIIIIIII
# Ga04g01150  MMMMMMMMMMMMMMM
# Ga04g01178  MMMMMMMMWWWWWWWIIIIIII
# Ga04g00895  MMMMMMMMMMMMMMM
# Ga04g00899  MMMMMMWWWWWWWWWIIIIIIIII
# Ga14g01135  MMMMMMMMWWWWWWWIIIIIII
# Ga14g00977  MMMMMMMMMMMMMMM
# Ga14g00978  MMMMMMWWWWWWWWWIIIIIIIII
# Ga04g00840  MMMMMMMMMMMWWWWIIII
# Ga04g00833  MMMMMMMMMMMMMMM
# Ga04g00756  MMMMMMMMMMMMMMM
# Ga04g00771  MMMMMMMMMMMMMMM
# Ga04g00759  MMMMMMMMMMMMMMM
# Ga04g00758  MMMMMMMMMMMMMMM
# Ga04g00749  MMMMMMMMMMMMMMM
# Ga04g00732  MMMMMMMMMMMMMMM
# Ga04g00728  MMMMMMMMMMMMMMM
# Ga04g00703  MMMMMMMMMMMMMMM
# Ga04g00680  MMMMMMMMWWWWWWWIIIIIII
# Ga04g00678  MMMMMMMMMMMMMMM
# Ga04g00656  MMMMMMMMMMMMMMM
# Ga04g00652  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g00641  MMMMMMMMMMMMMMM
# Ga04g00623  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g00590  MMMMMMMMMMMMMMM
# Ga04g00573  MMMMMMMMMMMMMMM
# Ga04g00569  MMMMMMMMMMMMMMM
# Ga04g00545  MMMMMMMMMMMMMMM
# Ga04g00512  MMMMMMMMMMMMMMM
# Ga04g00486  MMMMMMMMMMMMMMM
# Ga04g00480  MMMMMMMMMMMMMMM
# Ga04g00433  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g00411  MMMMMMMMMMMMMMM
# Ga14g01388  MMMMMMMMMMMMMMM
# Ga04g00396  MMMMMMMMMMMMMMM
# Ga04g00404  MMMMMMMMMMMMMMM
# Ga04g00389  MMMMMMMMMMMMMMM
# Ga04g00388  MMMMMMMMWWWWWWWIIIIIII
# Ga04g00376  MMMMMMMMMMMMMMM
# Ga04g00148  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g00139  MMMMMMMMMMMMMMM
# Ga04g00188  MMMMMMWWWWWWWWWIIIIIIIII
# Ga04g00347  MMMMMMWWWWWWWWWIIIIIIIII
# Ga04g00338  MMMMMMMMMMMMMMM
# Ga04g00299  MMMMMMMMWWWWWWWIIIIIII
# Ga04g00294  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g00279  MMMMMMMMMMMMMMM
# Ga04g00275  MMMMMMMMMMMMMMM
# Ga04g00250  MMMMMMMMMMMMMMM
# Ga04g00217  MMMMMMMMMMMMMMM
# Ga04g00216  MMMMMMMMMMMMMMM
# Ga04g00111  MMMMMMMMMMMMMMM
# Ga04g00096  MMMMMMWWWWWWWWWIIIIIIIII
# Ga04g00079  MMMMMMMWWWWWWWWIIIIIIII
# Ga04g00065  MMMMMMMMMMMMMMM
# Ga04g00062  MMMMMMMMMMMMMMM
# Ga04g00060  MMMMMMMMMMMMMMM
# Ga14g00305  MMMMMMMMWWWWWWWIIIIIII
# Ga14g00319  MMMMMMMMMMMMMMM
# Ga14g00301  MMMMMMMMMMMMMMM
# Ga14g00311  MMMMMMMMMMMMMMM
# Ga14g00286  MMMMMMMMMMMMMMM
# Ga13g00020  MMMMMMMMWWWWWWWIIIIIII
# Ga13g00025  MMMMMMMMMMMMMMM
# Ga13g00086  MMMMMMMMMMMMMMM
# Ga13g00075  MMMMMMMMMMMMMMM
# Ga13g00101  MMMMMMMMMMMMMMM
# Ga13g00179  MMMMMMWWWWWWWWWIIIIIIIII
# Ga13g00149  MMMMMMMMMMMMMMM
# Ga13g00189  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga13g00190  MMMMMMMMMMMMMMM
# Ga13g00211  MMMMMMMMMMMMMMM
# Ga13g00217  MMMMMMWWWWWWWWWIIIIIIIII
# Ga13g00209  MMMMMMMMMMMMMMM
# Ga13g00226  MMMMMMMMMMMMMMM
# Ga13g00228  MMMMMWWWWWWWWWWIIIIIIIIII
# Ga13g00231  MMMMMMMMMMMMMMM
# Ga13g00258  MMMMMMMMMMMMMMM
# Ga13g00595  MMMMMMMMMWWWWWWIIIIII
# Ga13g00298  MMMMMMMMMMMWWWWIIII
# Ga13g00611  MMMMMMMMMMMMMMM
# Ga13g00318  MMMMMMMMMMMMMMM
# Ga14g01217  MMMMMMMMMMMMMMM
# Ga14g01215  MMMMMMMMMMMMWWWIII
# Ga05g02188  MMMMMMMMMMMMMMM
# Ga05g02168  MMMMMMMMWWWWWWWIIIIIII
# Ga05g02176  MMMMMMMMMMMMMMM
# Ga05g02174  MMMMMMMMMMMMMMM
# Ga05g02237  MMMMMMMMMMMMMMM
# Ga05g02250  MMMMMMMMMMMMMMM
# Ga05g02259  MMMMMMMMMMMMMMM
# Ga05g02309  MMMMMMMMMMMMMMM
# Ga05g02349  MMMMMMMMMMMMMMM
# Ga05g02363  MMMMMMMMMMMMMMM
# Ga05g02368  MMMMMMMMMMMMMMM
# Ga05g02391  MMMMMMMMMMMMMMM
# Ga05g02384  MMMMMMMMMMMMMMM
# Ga05g02394  MMMMMMWWWWWWWWWIIIIIIIII
# Ga05g02404  MMMMMMMMMMMMMMM
# Ga05g02412  MMMMMMMMMMMMMMM
# Ga05g02418  MMMMMMMWWWWWWWWIIIIIIII
# Ga05g02475  MMMMMMMMMMMMMMM
# Ga05g02527  MMMMMMMMMMMMMMM
# Ga05g02524  MMMMMMMMMMMMMMM
# Ga05g02578  MMMMMMMMMMMMMMM
# Ga05g02570  MMMMMMMMMMMMMMM
# Ga05g02582  MMMMMMMMMWWWWWWIIIIII
# Ga05g02588  MMMMMMMMMMMMMMM
# Ga05g02597  MMMMMMMWWWWWWWWIIIIIIII
# Ga05g02620  MMMMMMMMMMMMMMM
# Ga05g02646  MMMMMMWWWWWWWWWIIIIIIIII
# Ga05g02644  MMMMMMMMMMMMMMM
# Ga05g02652  MMMMMMMMMMMMMMM
# Ga05g02658  MMMMMMMMMMMMMMM
# Ga05g02665  MMMMMMMMMMMMMMM
# Ga05g02702  MMMMMMMMMMMMMMM
# Ga05g02723  MMMMMMMMMMMMMMM
# Ga05g02717  MMMMMMMMMMMMMMM
# Ga05g02760  MVVVVVMMMMMMMMMDDDDD
# Ga05g02748  MMMMMMMMMMMMMMM
# Ga05g02752  MMMMMMMWWWWWWWWIIIIIIII
# Ga05g02753  MMMMMMMMMMMMMMM
# Ga05g02771  MMMMMMWWWWWWWWWIIIIIIIII
# Ga05g02814  MMMMMMMMMMMMMMM
# Ga05g02831  MMMMMMMMMMMMMMM
# Ga05g02846  MMMMMMMMMMMMMMM
# Ga05g02859  MMMMMMWWWWWWWWWIIIIIIIII
# Ga05g02905  MMMMMMMMMWWWWWWIIIIII
# Ga05g02915  MMMMMMMMWWWWWWWIIIIIII
# Ga05g02945  MMMMMMMMMMMMMMM
# Ga14g01322  MMMMMMMMMMMMMMM
# Ga05g03015  MMMMMMMMMMMMMMM
# Ga05g03010  MMMMMMMWWWWWWWWIIIIIIII
# Ga05g02996  MVVVVMMMMMMMMMMDDDD
# Ga05g02994  MMMMMMMMMMMMMMM
# Ga05g02980  MMMMMMMMMMMMMMM
# Ga05g03043  MMMMMMMMMMMMMMM
# Ga05g03081  MMMMMMMMMMMMMMM
# Ga05g03087  MMMMMMMMMMMMMMM
# Ga05g03084  MMMMMMMWWWWWWWWIIIIIIII
# Ga05g03078  MMMMMMMMMMMMMMM
# Ga05g03075  MMMMMMMWWWWWWWWIIIIIIII
# Ga05g03177  MMMMMMMMWWWWWWWIIIIIII
# Ga05g03235  MMMMMMMMMMMMMMM
# Ga05g03229  MMMMMMWWWWWWWWWIIIIIIIII
# Ga05g03185  MMMMMMMMMMMMMMM
# Ga05g03350  MMMMMMMMMMMMMMM
# Ga05g03399  MMMMMMMMMMMMMMM
# Ga05g03439  MMMMMMMMMMMMMMM
# Ga14g01945  MMMMMMMMMMMMMMM
# Ga05g03458  MMMMMMMMMMMMMMM
# Ga14g01780  MMMMMMMMMMMMMMM
# Ga07g00004  MMMMMMMMMMMMMMM
# Ga05g03486  MMMMMMMMWWWWWWWIIIIIII
# Ga05g04046  MMMMMMMMMMMMMMM
# Ga05g03375  MMMMMMMMMMMMMMM
# Ga05g03364  MMMMMMMMWWWWWWWIIIIIII
# Ga05g03508  MMMMMMWWWWWWWWWIIIIIIIII
# Ga05g03532  MMMMMMMMWWWWWWWIIIIIII
# Ga05g03571  MMMMMMMMWWWWWWWIIIIIII
# Ga05g03572  MMMMMMMMMMMMMMM
# Ga05g03579  MMMMMMMMMMMMMMM
# Ga05g03668  MMMMMMMMWWWWWWWIIIIIII
# Ga05g04025  MMMMMMMMMMMMMMM
# Ga05g03641  MMMMMMMMMMMMMMM
# Ga05g03685  MMMMMMMMMMMMMMM
# ...
# Ga12g01822  IIIIIDIMMMMMMMIIDDDDDDD
# Ga12g01707  DDDDDDDMMMMMMMIDIIIIIII
# Ga12g01562  DDDDDDDMMMMMMMIDIIIIIII
# Ga12g01267  DDDDDDDMMMMMMMIDIIIIIII
# Ga12g01090  DDDDDDDMMMMMMMIDIIIIIII
# Ga12g02703  DDDDDDDMMMMMMMIDIIIIIII
# Ga05g01052  DDDDDDDMMMMMMMIDIIIIIII
# Ga05g01548  DDDDDDDMMMMMMMIIIIIIIID
# Ga05g02113  DDDDDDDMMMMMMMIDIIIIIII
# Ga05g02118  IIIDIDIMMMMMMMIDDDDMM
# Ga13g00696  DDDDDDDMMMMMMMIDIIIIIII
# Ga13g00851  DDDDDDDMMMMMMMIIIIIIIID
# Ga13g01131  IIIDIDIMMMMMMMIIIDDDDDD
# Ga13g01900  IIIDIDIMMMMMMMIIIDDDDDD
# Ga01g01313  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga02g01169  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga03g02080  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga05g02229  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga05g02367  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga06g00462  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga07g01488  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga07g01797  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga08g00638  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga08g01498  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga08g01746  DDDIDDDMMMMMMIIIIIIMMD
# Ga08g02525  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga14g01717  IIIIIDIMMMMMMDDDDDMMM
# Ga09g01078  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga09g01577  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga09g01818  IIIIIIIMMMMMMIIDDDDDDDDD
# Ga09g02267  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga10g01875  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga10g00967  IIIIIIIMMMMMMIIDDDDDDDDD
# Ga11g02701  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga11g02579  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga11g02574  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga11g02529  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga11g01270  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga11g00058  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga12g02440  IIIIIIIMMMMMMIIDDDDDDDDD
# Ga12g02122  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga05g00451  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga05g01044  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga13g00845  IIIIIIIMMMMMMIIDDDDDDDDD
# Ga13g01364  IIIIIDIMMMMMMIIIDDDDDDDD
# Ga01g01636  DDDIDDDMMMMMIIIIIIMMIDD
# Ga04g01859  IIIIIDIMMMMMIIIIDDDDDDDDD
# Ga04g01292  IIIIIIIMMMMMIIIDDDDDDDDDD
# Ga14g01947  IIIIIDIMMMMMIIIIDDDDDDDDD
# Ga06g01647  IIIIIDIMMMMMIIIIDDDDDDDDD
# Ga06g02167  IIIIIDIMMMMMIIIIDDDDDDDDD
# Ga09g00479  IIIIIDIMMMMMIIIIDDDDDDDDD
# Ga09g02107  IIIIIDIMMMMMIIIDDDDDDDDM
# Ga11g03545  IIIIIDIMMMMMIIIIDDDDDDDDD
# Ga11g02404  IIIIIIIMMMMMIIIDDDDDDDDDD
# Ga12g02535  IIIIIDIMMMMMIIIIDDDDDDDDD
# Ga12g02575  IIIIIDIMMMMMIIIIDDDDDDDDD
# Ga05g01598  IIIIIDIMMMMMIIIIDDDDDDDDD
# Ga13g00596  IIIIIDIMMMMIIIIIDDDDDDDDDD
# Ga05g02330  IIIIIDIMMMMIIIIIDDDDDDDDDD
# Ga06g00900  IIIIIDIMMMMIIIIIDDDDDDDDDD
# Ga08g01891  IIIIIIIMMMMIIIIDDDDDDDDDDD
# Ga08g01902  IIIIIDIMMMMIIIIIDDDDDDDDDD
# Ga08g00810  IIIIIDIMMMMIIIIIDDDDDDDDDD
# Ga09g00761  IIIIIDIMMMMIIIIIDDDDDDDDDD
# Ga05g00763  IIIIIDIMMMMIIIIIDDDDDDDDDD
# Ga13g02014  IIIIIDIMMMMIIIIIDDDDDDDDDD
# Ga14g00674  IIIDIDIMMMIIIIIIIDDDDDDDDDD
# Ga08g00323  IIIIIDIMMMIIIIIIDDDDDDDDDDD
# Ga11g02458  IIIDIDIMMMIIIIIIIDDDDDDDDDD
# Ga05g00401  IIIIIIIMMMIIIIIDDDDDDDDDDDD
# Ga04g01139  IIIIIDIMMIIIIIIIDDDDDDDDDDDD
# Ga11g01487  IIIIIDIMMIIIIIIIDDDDDDDDDDDD
# Ga05g01987  IIIIIDIMMIIIIIIIDDDDDDDDDDDD
# Ga03g02452  DDDDDDDDMMMMMMMVVVVVVVV
# Ga04g01227  IIIIIIIIMMMMMMMWWWWWWWW
# Ga14g00265  DDDDDDDDMMMMMVVVVVVVVVVDD
# Ga06g00173  DDDDDDDDMMMMMMMVVVVVVVV
# Ga06g02055  DDDDDDDDMMMMMMMVVVVVVVV
# Ga07g00311  DDDDDDDDMMMMMMMVVVVVVVV
# Ga07g00309  DDDDDDDDMMMMMMMVVVVVVVV
# Ga07g02144  IIIIIIIIMMMMMMMWWWWWWWW
# Ga08g01300  IIIIIIIIMMMMMMMWWWWWWWW
# Ga08g01411  DDDDDDDDMMMMMMMVVVVVVVV
# Ga09g01355  IIIIIIIIMMMMMMMWWWWWWWW
# Ga10g02353  DDDDDDDDMMMMMMMVVVVVVVV
# Ga10g02048  IIIIIIIIMMMMMMMWWWWWWWW
# Ga10g00688  DDDDDDDDMMMMMMMVVVVVVVV
# Ga11g01027  DDDDDDDDMMMMMMMVVVVVVVV
# Ga11g00563  DDDDDDDDMMMMMMMVVVVVVVV
# Ga11g00366  DDDDDDDDMMMMMMMVVVVVVVV
# Ga13g01976  IIIIIIIIMMMMMMMWWWWWWWW
# Ga02g01451  DDDDDDDIVVVVVVVVVVMMMMDDDD
# Ga08g02353  IIIIIDIIMMMMMMMMWWWWWW
# Ga11g02200  IIIIIDIIMMMMMMMMWWWWWW
# Ga01g00020  IIIIIDIIMMMMMMMWWWWWWID
# Ga07g01079  IIIIIDIDMMMMMMMMMWWWW
# Ga11g02766  IIIDIDIIMMMMMMMMMWWWW
# Ga02g00120  DDDIDIDIVVVVVVVVVVVIDDDDDDDDDD
# Ga02g01240  IDIDIDIDMMMMVVVVVVIDDDDDDD
# Ga01g02394  IDIDIDIDMMMMVVVVVVIDDDDDDD
# Ga01g02166  DDDIDIDIVVVVVVVVVVIIDDDDDDDDDD
# Ga09g00765  DDDIDIDIVVVVVVVVVVIIDDDDDDDDDD
# Ga09g01140  IDIDIDIDMMMMMMMMMMID
# Ga12g00461  IIIDIDIDMMMMMMMMMMDD
# Ga05g00739  IIIDIDIDMMMMMMMMMMDD
# Ga05g01092  IDIDIDIDMMMMVVVVVVIDDDDDDD
# Ga01g00811  IIIIIDIDMMMMMMMMMDDDD
# Ga01g02486  IIDIDIDIVVVVVVVVVIDDDDDDDDDDDD
# Ga01g01703  IIIIIIIIMMMWWWWWWDDMMMM
# Ga03g00897  DDDIDIDDMMMMMMWWWIIIIIII
# Ga04g00821  IIIDIDIIMMMMMMMMMDDDD
# Ga04g00718  DDDIDIDDMMMMMMWWWIIIIIII
# Ga11g02534  DDDIDIDDMMMMWWWWWIIIIIIIII
# Ga11g02134  IIDIDIDIVVVVVVVVVIDDDDDDDDDDDD
# Ga05g00995  IIIIIIIIMMWWWWWWWIIIIIDDDDDD
# Ga13g01486  IIIIIIIIMMWWWWWWWDMMMMM
# Ga01g01302  DDDDDDDDMMMMMVVVIIIIIIIDD
# Ga03g00866  IIIDIDIIVVVVVVVVIDDDDDDDDDDDDD
# Ga04g01599  IIIDIDIIMMMMMMMMIDDDDD
# Ga13g00152  IIIDIDIIVVVVVVVVIDDDDDDDDDDDDD
# Ga05g02351  IIIDIDIIMMMMMMMMIDDDDD
# Ga08g01437  IIIDIDIIVVVVVVVVIDDDDDDDDDDDDD
# Ga09g02443  IIIDIDIIVVVVVVVVIDDDDDDDDDDDDD
# Ga11g02843  IIIDIDIIMMMMMMMMIDDDDD
# Ga11g01776  IIDIDIDIVVVVVVVVIIDDDDDDDDDDDD
# Ga12g00607  IIIDIDIIMMMMMMMMIDDDDD
# Ga12g00799  IIIDIDIIVVVVVVVVIDDDDDDDDDDDDD
# Ga05g00447  IIIDIDIIMMMMMMMMIDDDDD
# Ga13g01714  IIIDIDIIMMMMMMMMIDDDDD
# Ga01g00723  IIIDIDIIMMMMMMMIIDDDDDD
# Ga01g00813  IIIIIDIIMMMMMMMIDDDDDDD
# Ga02g01532  DDDDDDDDMMMMMMMIIIIIIII
# Ga03g02265  IIIIIDIDMMMMMMMIIDDDDDD
# Ga03g01457  DDDDDDDDMMMMMMMIIIIIIII
# Ga03g01437  IIIIIIIDMMMMMMMIDDDDDDD
# Ga03g01440  DDDDDDDDMMMMMMMIIIIIIII
# Ga04g01594  IIIIIDIIMMMMMMMIDDDDDDD
# Ga04g00365  DDDDDDDDMMMMMMMIIVVVVVV
# Ga05g02420  IIIIIDIIMMMMMMMIDDDDDDD
# Ga05g02787  DDDDDDDDMMMMMMMIIIIIIII
# Ga05g02889  IIIIIDIIMMMMMMMIDDDDDDD
# Ga05g03658  DDDDDDDDMMMMMMMIIIIIIII
# Ga06g00059  IIIIIDIIMMMMMMMIDDDDDDD
# Ga06g00731  IIIIIIIDMMMMMMMIDDDDDDD
# Ga07g00516  IIIDIDIIMMMMMMMIIDDDDDD
# Ga07g01027  IIIIIDIIMMMMMMMIDDDDDDD
# Ga07g01847  DDDDDDDDMMMMMMMIIIVVVVV
# Ga08g01084  IIIIIDIIMMMMMMMIDDDDDDD
# Ga08g01480  DDDDDDDDMMMMMMMIIVVVVVV
# Ga08g01588  DDDDDDDDMMMMMMMIIIIIIII
# Ga09g00234  DDDDDDDDMMMMMMMIIIIIIII
# Ga09g00339  IIIDIDIIMMMMMMMIIDDDDDD
# Ga10g01639  IIIDIDIIMMMMMMMIIDDDDDD
# Ga11g01356  DDDDDDDDMMMMMMMIIIIIIII
# Ga12g02185  DDDDDDDDMMMMMMMIIVVVVVV
# Ga12g01803  DDDDDDDDMMMMMMMIIIIIIII
# Ga05g00604  IIIIIDIIMMMMMMMIDDDDDDD
# Ga05g01111  IIIIIIIDMMMMMMMIDDDDDDD
# Ga13g02272  DDDDDDDDMMMMMMMIIIIIIII
# Ga12g02285  IIIDIDIIMMMMMMIIIDDDDDDD
# Ga01g02095  IIIIIDIIMMMMMMIIDDDDDDDD
# Ga02g00493  DDDDDDDDMMMMMMIIIIIIIIID
# Ga03g01268  IIIIIDIIMMMMMMIIDDDDDDDD
# Ga13g00175  IIIIIDIIMMMMMMIIDDDDDDDD
# Ga05g02882  DDDDDDDDMMMMMMIIVVVVVVVD
# Ga07g01700  IIIIIDIDMMMMMMIIIDDDDDDD
# Ga08g00696  IIIIIDIIMMMMMMIIDDDDDDDD
# Ga08g02280  IIIDIDIIMMMMMMIIIDDDDDDD
# Ga09g02314  IIIIIIIDMMMMMMIIDDDDDDDD
# Ga11g01846  IIIIIDIDMMMMMMIIIDDDDDDD
# Ga11g00114  IIIIIDIDMMMMMMIIIDDDDDDD
# Ga11g00086  IIIIIDIIMMMMMMIIDDDDDDDD
# Ga12g00341  IIIDIDIIMMMMMMDDDMMIDD
# Ga13g00359  IIIIIDIIMMMMMMIIDDDDDDDD
# Ga13g02261  IIIIIDIIMMMMMMIIDDDDDDDD
# Ga01g01777  IIIIIDIDMMMMMIIIIDDDDDDDD
# Ga03g00421  IIIDIDIIMMMMMIIIIDDDDDDDD
# Ga09g02072  IIIDIDIIMMMMMDDDDDMMMI
# Ga10g01289  IIIDIDIIMMMMMIIIIDDDDDDDD
# Ga12g00219  IIIDIDIDMMMMMIIIIIDDDDDDD
# Ga05g00957  IIIDIDIIMMMMMIIIIDDDDDDDD
# Ga05g02508  IIIDIDIIMMMMIIIIIDDDDDDDDD
# Ga12g00803  IIIIIDIIMMMMIIIIDDDDDDDDDD
# Ga13g01214  IIIIIDIDMMMMIIIIIDDDDDDDDD
# Ga02g00383  IIIIIDIIMMMIIIIIDDDDDDDDDDD
# Ga05g00354  IDIDIDIDMMMIIIIIIIIDDDDDDDD
# Ga01g01075  IIIIIIIIIMMMMMMWWWWWWWWW
# Ga01g01317  DDDDDDDDDMMMMMMVVVVVVVVV
# Ga10g01027  DDDDDDDDDMMMMMVVVVVVVVVVD
# Ga03g01586  DDDDDDDDDMMMMMMVVVVVVVVV
# Ga04g01699  IIIIIIIIIMMMMMMWWWWWWWWW
# Ga04g00601  DDDDDDDDDMMMMMMVVVVVVVVV
# Ga06g00282  DDDDDDDDDMMMMVVVVVVVVVVVDD
# Ga07g01613  DDDDDDDDDMMMMMMVVVVVVVVV
# Ga07g01497  DDDDDDDDDMMMMVVVVVVVVVVVDD
# Ga09g02357  DDDDDDDDDMMMMMMVVVVVVVVV
# Ga10g02418  IIIIIIIIIMMMMMMWWWWWWWWW
# Ga10g01176  IIIIIIIIIMMMMWWWWWWWWWWWII
# Ga11g03732  IIIIIIIIIMMMMMMWWWWWWWWW
# Ga11g02842  IIIIIIIIIMMMMMMWWWWWWWWW
# Ga11g01646  IIIIIIIIIMMMMMMWWWWWWWWW
# Ga14g01490  DDDDDDDDDMMMMMVVVVVVVVVVD
# Ga12g00230  DDDDDDDDDMMMMVVVVVVVVVVVDD
# Ga12g01131  DDDDDDDDDMMMMVVVVVVVVVVVDD
# Ga12g02713  IIIIIIIIIMMMMMMWWWWWWWWW
# Ga01g00941  DDDDDDDDIVVVVVVVVVVVVVIDDDDDDD
# Ga08g01789  IIIIIDIDIMMMMMMMMWWWWW
# Ga09g01748  DDDDDDDDIVVVVVVVVVVVVVIDDDDDDD
# Ga09g02501  IIIIIDIDIMMMMMMMMWWWWW
# Ga01g00949  IIIDIDIDIMMMMMMMWWWWWII
# Ga06g00799  IIIDIDIDIMMMMMMMMMWWW
# Ga09g00296  IIIDIDIDIMMMMMMMMMWWW
# Ga10g02616  DDDDDDDDDMMMMMMVVVVVVIII
# Ga11g03375  DDDDDDDDDMMMMMMVVVVVVIII
# Ga11g00339  IIIDIDIDIMMMMMMMMMWWW
# Ga07g00684  IIDIDIDIDMMMMMMMMMMW
# Ga10g01717  DDIDIDIDIVVVVVVVVVVIDDDDDDDDDD
# Ga13g01106  IDDIDIDIDMMMMMMMMMMI
# Ga14g00696  IDIDIDIDIVVVVVVVVVIDDDDDDDDDDD
# Ga05g02355  IIDIDIDIDMMMMMMMMMIDD
# Ga05g03664  DDDDDDDDDMMMMVVVVVIVVVVVDD
# Ga06g00304  IIDIDIDIDMMVVVVVVVIDDDDDDDDD
# Ga06g01483  IIDIDIDIDMMVVVVVVVIDDDDDDDDD
# Ga07g00328  IIDIDIDIDMMMMMMMMMIDD
# Ga11g02874  IIIDIDIDIMMMMMMMMMDDD
# Ga08g01491  IIDIDIDIDMMVVVVVVIIDDDDDDDDD
# Ga10g02314  DDDDDDDDDMMVVVVVVIIIMMMM
# Ga13g01723  IIIDIDIDIMMMMMMMMIDDDD
# Ga01g01847  IIIDIDIDIMMMMMMMIIDDDDD
# Ga05g03687  IIIDIDIDIMMMMMMMIIDDDDD
# Ga09g02241  IIIIIDIDIMMMMMMMIDDDDDD
# Ga12g01861  IIIDIDIDIVVVVVVVIIDDDDDDDDDDDD
# Ga13g02044  IIIIIDIDIMMMMMMMIDDDDDD
# Ga01g01085  DDDIDDDDDMMMMMMIIIIIIIID
# Ga01g01144  IIIIIIIDIMMMMMMIDDDDDDDD
# Ga02g00181  DDDIDIDDDMMMMMMIIIIIIIDD
# Ga03g02236  DDDDDDDDDMMMMMMIIIIIIIII
# Ga03g02101  IIIIIIIDIMMMMMMIDDDDDDDD
# Ga03g01868  DDDDDDDDDMMMMMMIIIIIIIII
# Ga03g00660  DDDDDDDDDMMMMMMIIIIIIIII
# Ga07g00128  DDDDDDDDDMMMMMMIIIVVVVVV
# Ga07g00685  IIIIIIIDIMMMMMMIDDDDDDDD
# Ga08g00863  IIIIIIIDIMMMMMMIDDDDDDDD
# Ga08g01824  DDDDDDDDDMMMMMMIIIVVVVVV
# Ga08g02323  DDDDDDDDDMMMMMMIIIIIIIII
# Ga11g02417  DDDDDDDDDMMMMMMIIIIIIIII
# Ga11g01321  IIIIIDIDIMMMMMMIIDDDDDDD
# Ga12g01418  IIIIIIIDIMMMMMMIDDDDDDDD
# Ga05g02075  DDDDDDDDDMMMMMMIIIIIIIII
# Ga05g02128  IIIIIIIDIMMMMMMIDDDDDDDD
# Ga02g00258  IIIIIIIDIMMMMMIIDDDDDDDDD
# Ga03g01725  IIIIIIIDIMMMMMIIDDDDDDDDD
# Ga04g00539  IIIIIIIDIMMMMMIIDDDDDDDDD
# Ga06g01854  IIIIIIIDIMMMMMIIDDDDDDDDD
# Ga06g01880  IIIIIIIIIMMMMMIDDDDDDDDDD
# Ga10g00279  IIIIIIIDIMMMMMIIDDDDDDDDD
# Ga11g02971  IIIIIIIDIMMMMMIIDDDDDDDDD
# Ga12g01074  IIIIIIIDIMMMMMIIDDDDDDDDD
# Ga05g01002  IIIIIIIDIMMMMMIIDDDDDDDDD
# Ga13g01250  IIIIIIIIIMMMMMIDDDDDDDDDD
# Ga01g02232  IIIIIIIIIMMMMIIDDDDDDDDDDD
# Ga07g01775  IIIIIIIIIMMMMIIDDDDDDDDDDD
# Ga08g01021  IIIIIDIDIMMMMDDDDDDMMMI
# Ga09g00996  IIIIIIIIIMMMMIIDDDDDDDDDDD
# Ga09g02212  IIIIIIIIIMMMMIIDDDDDDDDDDD
# Ga11g02572  IIIIIIIIIMMMMIIDDDDDDDDDDD
# Ga12g00688  IIIIIIIIIMMMMIIDDDDDDDDDDD
# Ga12g01641  IIIDIDIDIMMMMIIIIIDDDDDDDD
# Ga14g00095  IIIIIIIIIMMMMIIDDDDDDDDDDD
# Ga05g00107  IIIIIIIIIMMMMDDDDMIDDDDDD
# Ga08g00857  IIDIDIDIDMMMIIIIIIIDDDDDDDD
# Ga13g00680  IIIIIIIDIMMMIIIIDDDDDDDDDDD
# Ga11g00325  IIDIDIDIDMMIIIIIIIIDDDDDDDDD
# Ga01g00609  DDDDDDDDDDMMMMMVVVVVVVVVV
# Ga01g01018  IIIIIIIIIIMMMMMWWWWWWWWWW
# Ga01g01092  DDDDDDDDDDMMMMMVVVVVVVVVV
# Ga03g01390  IIIIIIIIIIMMMMMWWWWWWWWWW
# Ga06g00366  IIIIIIIIIIMMMMMWWWWWWWWWW
# Ga06g01740  DDDDDDDDDDMMMMMVVVVVVVVVV
# Ga07g01614  IIIIIIIIIIMMMMMWWWWWWWWWW
# Ga09g00528  IIIIIIIIIIMMMMMWWWWWWWWWW
# Ga06g01038  DDDDDDDDDDMMMMMVVVVVVVVVV
# Ga11g00297  IIIIIIIIIIMMMMMWWWWWWWWWW
# Ga07g00880  DDDDDDDDDIVVVVVVVVVVVVVIDDDDDD
# Ga11g00761  DDDDDDDDDIVVVVVVVVVVVVVIDDDDDD
# Ga13g01783  DDDDDDDDDIVVVVVVVVVVVVVIDDDDDD
# Ga01g01041  IIIDIDIDIDMMMMMMMMMWW
# Ga02g00897  IIIDIDIDIDMMMMMMMMMWW
# Ga02g01566  DDDIDIDDDIVVVVVVVVVVVIDDDDDDDD
# Ga11g02680  IIIDIDIDIDMMMMMMMMMWW
# Ga08g00166  DDDIDIDDDIVVVVVVVVVVIIDDDDDDDD
# Ga12g02707  DDDIDIDIDIVVVVVVVVVVIDDDDDDDDD
# Ga13g02518  DDDIDIDIDIVVVVVVVVVVIDDDDDDDDD
# Ga01g01658  IDDIDIDIDIVVVVVVVVVIDDDDDDDDDD
# Ga06g00058  IDIDIDIDIDMMMMMMMMMID
# Ga14g01065  IDDIDIDIDIVVVVVVVVVIDDDDDDDDDD
# Ga09g00238  IDDIDIDIDIVVVVVVVVVIDDDDDDDDDD
# Ga09g01803  IDDIDIDIDIVVVVVVVVVIDDDDDDDDDD
# Ga13g01950  IDDIDIDIDIVVVVVVVVVIDDDDDDDDDD
# Ga14g01002  IDDIDIDIDIVVVVVVVVIIDDDDDDDDDD
# Ga08g02215  IDDIDIDIDIVVVVVVVVIIDDDDDDDDDD
# Ga09g02523  DDDDDDDDDDMVVVVVVVIIIMMMM
# Ga05g01283  IDDIDIDIDIVVVVVVVVIIDDDDDDDDDD
# Ga05g01774  DDDDDDDDDDMMMMMVVVIIVVVVV
# Ga05g01854  IDDIDIDIDIVVVVVVVVIIDDDDDDDDDD
# Ga12g02226  DDDDDDDDDDMVVVVVVIIMMMMII
# Ga12g02621  DDDDDDDDDIVVVVVVVIIIIMMMDDD
# Ga01g02271  IIIIIDIDIIMMMMMMIDDDDDDD
# Ga05g02683  DDDIDDDDDDMMMMMMIIIVVVVV
# Ga06g01747  IIIDIDIDIIMMMMMMIIDDDDDD
# Ga09g00945  DDDDDDDDDIVVVVVVIIIIIIIIDDDDDD
# Ga10g02502  DDDIDDDDDDMMMMMMIIIIIIII
# Ga10g00382  DDDIDDDDDDMMMMMMIIIIIIII
# Ga12g00369  DDDIDDDDDDMMMMMMIIIIIIII
# Ga03g02012  IIIIIDIDIIMMMMMIIDDDDDDDD
# Ga04g00452  DDDDDDDDDDMMMMMIIIIIIIIII
# Ga13g00173  DDDIDDDDDDMMMMMIIIIIIIIID
# Ga07g00624  IIIIIIIIIDMMMMMIDDDDDDDDD
# Ga10g02259  DDDIDDDDDDMMMMMIIIIIIIIID
# Ga11g00444  IIIIIDIDIDMMMMMIIIDDDDDDD
# Ga12g00279  DDDDDDDDDDMMMMMIIIIIIIIII
# Ga12g02377  DDDDDDDDDDMMMMMIIIIIIIIII
# Ga02g01015  IIIIIIIDIIMMMMIIDDDDDDDDDD
# Ga03g01882  IIIDIDIDIIMMMMIIIIDDDDDDDD
# Ga03g01482  IIIIIIIIIDMMMMIIDDDDDDDDDD
# Ga03g00719  IIIIIIIIIIMMMMIDDDDDDDDDDD
# Ga05g03406  IIIIIIIDIIMMMMIIDDDDDDDDDD
# Ga07g01532  IIIIIIIDIIMMMMIIDDDDDDDDDD
# Ga08g01971  IIIIIIIDIIMMMMIIDDDDDDDDDD
# Ga09g01167  IIIIIIIIIDMMMMIIDDDDDDDDDD
# Ga13g02097  DDDDDDDDDDMMMMIIIIIIIIIIID
# Ga04g00661  IIIDIDIDIDMMMIIIIIIDDDDDDDD
# Ga05g02699  IIIIIIIIIIMMMIIDDDDDDDDDDDD
# Ga14g00619  IIIIIIIIIIMMMIIDDDDDDDDDDDD
# Ga10g02681  IIIIIIIDIIMMMIIIDDDDDDDDDDD
# Ga05g01097  IIIIIIIIIIMMMIIDDDDDDDDDDDD
# Ga02g01271  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga03g02059  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga03g01834  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga04g01424  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga04g01190  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga14g00327  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga05g02300  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga05g03030  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga06g01010  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga07g01050  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga07g01054  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga07g01462  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga07g02080  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga07g02079  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga09g00751  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga11g03507  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga11g00979  DDDDDDDDDDDMMMMVVVVVVVVVVV
# Ga12g00630  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga12g00670  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga12g02443  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga12g02169  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga05g00367  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga13g02593  IIIIIIIIIIIMMMMWWWWWWWWWWW
# Ga01g00602  IIIDIDIDIDIMMMMMMMMWWW
# Ga06g01179  DDIDIDIDIDIVVVVVVVVVIDDDDDDDDD
# Ga06g01599  DDDIDDDDDDIVVVVVVVVVIIIIDDDDDD
# Ga02g01605  IIIDIDIDIDDMMVVVVVVIDDDDDDDD
# Ga07g00204  IIIDIDIDIDIMMMMMMMIDDDD
# Ga05g01664  DDDIDDDDDDDMMVVVVVIIIIIIIDDD
# Ga05g02341  DDDIDIDDDDDMMMMMMIIIIIII
# Ga07g00412  DDDIDIDDDDDMMMMMMIIIIIII
# Ga10g01917  DDDIDIDDDDDMMMMMMIIIIIII
# Ga03g00762  IIIDIDIDIDIMMMMMIIIDDDDDD
# Ga14g01053  IIIDIDIDIDIMMMMMIIIDDDDDD
# Ga01g01437  DDDDDDDDDDDMMMMIIIIIIIIIII
# Ga03g02170  IIIIIIIDIDIMMMMIIDDDDDDDDD
# Ga05g02782  DDDIDDDDDDDMMMMIIIIIIIIIID
# Ga07g01599  DDDIDDDDDDDMMMMIIIIIIIIIID
# Ga05g01524  DDDIDDDDDDDMMMMIIIIIIIIIID
# Ga01g00212  IIIIIIIIIDIMMMIIDDDDDDDDDDD
# Ga03g01223  IIIIIIIIIDIMMMIIDDDDDDDDDDD
# Ga04g00446  IIIIIIIIIDIMMMIIDDDDDDDDDDD
# Ga06g00948  IIIIIIIIIIIMMMIDDDDDDDDDDDD
# Ga07g02441  IIIIIIIIIIIMMMIDDDDDDDDDDDD
# Ga08g00121  IIIIIIIIIDIMMMIIDDDDDDDDDDD
# Ga12g02553  IIIIIIIIIDIMMMIIDDDDDDDDDDD
# Ga07g00907  IIIIIIIIIDIMMIIIDDDDDDDDDDDD
# Ga12g00054  DDDIDDDDDDDDMMVVVVVVVVVVVIDD
# Ga13g00808  DDDIDIDDDDDIVVVVVVVVVVVIDDDDDD
# Ga12g00653  IIIDIDIDIDIDMMMMMMMMWW
# Ga05g01394  IIIDIDIDIDIDMMMMMMMMWW
# Ga09g01249  IIIDIDIDIDDDMMMMMMMMID
# Ga06g00094  IIIDIDIDIDIIMMMMMMMDDDD
# Ga12g00131  DDDIDDDDDDDDMMVVVVIIIIIMMI
# Ga08g00932  DDDIDIDDDDDDMMMMMIIIIIIII
# Ga11g02800  IIIDIDIDIDIDMMMMIIIIDDDDDD
# Ga11g02697  IIIIIIIDIDIIMMMMIDDDDDDDDD
# Ga08g02368  DDIDIDIDIDDDMMMIIIIIIIIDDDD
# Ga05g00994  IIIDIDIDIDIIMMMIIIIDDDDDDDD
# Ga06g01528  IIIIIIIIIDIIMMIIDDDDDDDDDDDD
# Ga08g02508  IIIIIIIIIDIIMMIIDDDDDDDDDDDD
# Ga11g00491  IIIDIDIDIDIDMMIIIIIIDDDDDDDD
# Ga09g02390  DDDDDDDDDDDDIVVVVVVVVVVVVVIDDD
# Ga01g00626  DDDDDDDDDDDDDMVVVVVIIIIIIIIID
# Ga14g00277  IIIDIDIDIDIIIMMMMMMDDDDD
# Ga08g01366  DDDIDIDIDDDDDMMMMMIIIVVVV
# Ga11g02824  IIIIIDIDIDIIIMMMIIDDDDDDDDD
# Ga05g01730  IIIDIDIDIDIIIMMMIIIDDDDDDDD
# Ga13g01622  IIIDIDIDIDIIIMMMIIIDDDDDDDD
# Ga04g00886  DDDIDDDDDDDDDMMIIIIIIIIIIIID
# Ga04g00967  IIIIIIIDIDIIIMMIIDDDDDDDDDDD
# Ga08g00892  DDDIDDDDDDDDDMMIIIIIIIIIIIID
# Ga08g02229  IIIDIDIDIDIIDDMMMMMMIDDD
# Ga06g00215  DDDIDIDIDDDDDDMMMMIIIIIIII
# Ga13g01447  DDDIDIDIDDDDDDMMMMIIIIIIII
# Ga04g01413  DDDIDIDDDDDDDDMMMIIIIIIIIII
# Ga03g02272  DDDIDDDDDDDDDDMMIIIIIIIIIIII
# Ga06g00316  IIIDIDIDIDIIIIMMIIIDDDDDDDDD
# Ga02g00285  DDDDDDDDDDDDDDMIIIIIIIIIIIIII
# Ga10g00198  DDDIDIDDDDDDDDDMMIIIIIIIIIII
# Ga10g01065  IIIDIDIDIDIIDDDDMMMMMMM
# Ga08g02382  IIIDIDIDIDIIIDDDMMMIIIDDDDD
# Ga10g01053  IIIDIDIDIDIIIIIDDDDDDDDMMMI

# %% [markdown]
# ## Gene-set overrepresentation analysis on the top dissimilar genes
#
# Checking top dissimilar genes, i.e, only <=30% similarity along pseudotime

# %%
topDEgenes = df[df['alignment_similarity_percentage'] <= threshold_similarity]['Gene']
# print(topDEgenes); print(len(topDEgenes))
#可以做一个enrich看最不相似的基因主要富集到什么功能
os.makedirs("topDEgenes", exist_ok=True)
with open('topDEgenes/topDEgenes.txt', 'w') as f:
    for gene in topDEgenes[:n_top]:
        print(f"Processing gene: {gene}")
        gene_obj = aligner.results_map[gene]
        alignment_str = gene_obj.alignment_str
        f.write(f'{gene} {alignment_str}\n')
        # 1) 打印对齐字符串和彩色版本
        print(alignment_str)
        print(VisualUtils.color_al_str(alignment_str))
        print()
        print(gene_obj.al_visual)
        # 2) 画 alignment landscape
        gene_obj.landscape_obj.plot_alignment_landscape()
        plt.savefig(
            f'topDEgenes/plot_cost_{gene}_{prefix_ref}_vs_{prefix_query}.pdf',
            bbox_inches='tight'
        )
        plt.show()
        plt.close('all')
        # 3) 画 time series（带细胞）
        VisualUtils.plotTimeSeries(gene, aligner, plot_cells=True)
        plt.savefig(
            f'topDEgenes/plotTimeSeries_{gene}_{prefix_ref}_vs_{prefix_query}.pdf',
            bbox_inches='tight'
        )
        plt.show()
        plt.close('all')
        #VisualUtils.show_gene_alignment(gene, aligner, adata_ref, adata_query, annotation_colname, joint_cmap2)
        VisualUtils.visualize_gene_alignment(gene_obj, adata_ref, adata_query, annotation_colname, cmap=joint_cmap2)
        plt.savefig(
            f'topDEgenes/gene_alignment_{gene}_{prefix_ref}_vs_{prefix_query}.pdf',
            bbox_inches='tight'
        )
        plt.show()
        # plt.show()
        plt.close('all')
# Out:
# Processing gene: Ga01g02511
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
#
# 012345678901234567890123456789 Alignment index
#    0 1 2 3         45678901234 Reference index
# ---*-*-*-*---------***********
# ***-*-*-*-*********-----------
# 012 3 4 5 678901234            Query index
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD 5-state string
# Processing gene: Ga14g01058
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
#
# 012345678901234567890123456789 Alignment index
#    0 1 2 3         45678901234 Reference index
# ---*-*-*-*---------***********
# ***-*-*-*-*********-----------
# 012 3 4 5 678901234            Query index
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD 5-state string
# Processing gene: Ga03g00652
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
#
# 012345678901234567890123456789 Alignment index
#    0 1 2 3         45678901234 Reference index
# ---*-*-*-*---------***********
# ***-*-*-*-*********-----------
# 012 3 4 5 678901234            Query index
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD 5-state string
# Processing gene: Ga03g00447
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
#
# 012345678901234567890123456789 Alignment index
#    0 1 2 3         45678901234 Reference index
# ---*-*-*-*---------***********
# ***-*-*-*-*********-----------
# 012 3 4 5 678901234            Query index
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD 5-state string
# Processing gene: Ga04g01820
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
#
# 012345678901234567890123456789 Alignment index
#    0 1 2 3         45678901234 Reference index
# ---*-*-*-*---------***********
# ***-*-*-*-*********-----------
# 012 3 4 5 678901234            Query index
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD 5-state string
# Processing gene: Ga04g01317
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
#
# 012345678901234567890123456789 Alignment index
#    0 1 2 3         45678901234 Reference index
# ---*-*-*-*---------***********
# ***-*-*-*-*********-----------
# 012 3 4 5 678901234            Query index
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD 5-state string
# Processing gene: Ga12g01951
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
#
# 012345678901234567890123456789 Alignment index
#    0 1 2 3         45678901234 Reference index
# ---*-*-*-*---------***********
# ***-*-*-*-*********-----------
# 012 3 4 5 678901234            Query index
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD 5-state string
# Processing gene: Ga04g00697
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
#
# 012345678901234567890123456789 Alignment index
#    0 1 2 3         45678901234 Reference index
# ---*-*-*-*---------***********
# ***-*-*-*-*********-----------
# 012 3 4 5 678901234            Query index
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD 5-state string
# Processing gene: Ga05g02172
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
#
# 012345678901234567890123456789 Alignment index
#    0 1 2 3         45678901234 Reference index
# ---*-*-*-*---------***********
# ***-*-*-*-*********-----------
# 012 3 4 5 678901234            Query index
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD 5-state string
# Processing gene: Ga05g02544
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD
#
# 012345678901234567890123456789 Alignment index
#    0 1 2 3         45678901234 Reference index
# ---*-*-*-*---------***********
# ***-*-*-*-*********-----------
# 012 3 4 5 678901234            Query index
# IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD 5-state string

# %% [markdown]
# ## Clustering alignments
#
# Running experiment to determine the distance threshold for alignment clusters from hierarchical clustering. We aim to select a locally optimal threshold that gives a good trade-off between high mean Silhouette score and low number of clusters which can be biologically meaningful.

# %%
# ClusterUtils.run_clustering(aligner, metric='levenshtein', DIST_THRESHOLD=0.37) 
print('----------------------------3. Clustering alignments ---------------------')
df = ClusterUtils.run_clustering(aligner, metric='levenshtein', experiment_mode=True)
plt.savefig(f'clustering_genes_{prefix_ref}_vs_{prefix_query}.pdf', bbox_inches='tight')
# Out:
# ----------------------------3. Clustering alignments ---------------------
# Compute distance matrix
# - using levenshtein distance metric
# Experimental mode: exploring different thresholds
#  78%|███████▊  | 77/99 [11:54<03:24,  9.27s/it]
# -- Cluster diagnostic plots
# Potential candidates for distance threshold: a locally optimal thresholds that gives a good trade-off between high mean Silhouette score and low number of clusters

# %% [markdown]
# Run clustering with the chosen distance threshold. In this case we select 0.37

# %%
plt.close('all')

# %% [markdown]
# Visualise gene alignment grouped together in each cluster <br>
# Note: diagonals represent matches; vertical and horizontal paths could represent either warp matches or indels (mismatches)

# %%
ClusterUtils.run_clustering(aligner, metric='levenshtein', DIST_THRESHOLD=distance_threshold)
ClusterUtils.visualise_clusters(aligner,n_cols = 4, figsize= (5,3))
plt.savefig(f'clustering_genes_{distance_threshold}_{prefix_ref}_vs_{prefix_query}.pdf', bbox_inches='tight')
# Out:
# Compute distance matrix
# - using levenshtein distance metric
# run agglomerative clustering | distance threshold = 0.57
# silhouette_score:  0.5774107659061374
# Cluster ID | Number of genes in the cluster

# %% [markdown]
# Visualise the distance matrix used in the clustering

# %%
plt.close('all')

# %%
VisualUtils.plot_distmap_with_clusters(aligner)
plt.savefig(
    f'clustering_distmap_{distance_threshold}_{prefix_ref}_vs_{prefix_query}.png',
    bbox_inches='tight',
    dpi=72          # 清晰度够用且文件小；再降可改成 100 或 72
)

# %%
plt.close('all')

# %%
# ClusterUtils.print_cluster_average_alignments(aligner)
def get_cluster_average_alignments(aligner, gene_set, deterministic=True):
            cluster_alobjs = []
            for g in gene_set:
                cluster_alobjs.append(aligner.results_map[g])
            i = aligner.results[0].fwd_DP.T_len
            j = aligner.results[0].fwd_DP.S_len
            avg_alignment = ''
            tracked_path = []
            tracked_path.append([i,j])
            while(True):
                if(i==0 and j==0):
                    break
                backtrack_states_probs = {}
                backtrack_states_probs['M'] = 0 
                backtrack_states_probs['W'] = 0 
                backtrack_states_probs['V'] = 0 
                backtrack_states_probs['D'] = 0 
                backtrack_states_probs['I'] = 0 
                # record the count of each state at this [i,j] cell across all alignments 
                for a in cluster_alobjs:
                    backtract_state = a.landscape_obj.L_matrix_states[i,j]
                    if(backtract_state=='0'):
                        backtrack_states_probs['M']+=1 
                    elif(backtract_state=='1'):
                        backtrack_states_probs['W']+=1 
                    elif(backtract_state=='2'):
                        backtrack_states_probs['V']+=1 
                    elif(backtract_state=='3'):
                        backtrack_states_probs['D']+=1 
                    elif(backtract_state=='4'):
                        backtrack_states_probs['I']+=1 
                # compute the proportion of the state for the [i,j] cell
                for state in backtrack_states_probs.keys(): 
                    backtrack_states_probs[state] = backtrack_states_probs[state]/len(cluster_alobjs) 
                if(deterministic):
                    # take the most probable state based on max frequent state of this [i,j] cell
                    cs = np.argmax(np.asarray(list(backtrack_states_probs.values())) )
                else:
                    # sample a state from the state frequency distribution
                    cs = Utils.sample_state(np.asarray(list(backtrack_states_probs.values()) ) )
                if(cs==0):
                    i = i-1
                    j = j-1
                    avg_alignment = 'M' + avg_alignment 
                elif(cs==1 or cs==3):
                    j= j-1
                    if(cs==1):
                        avg_alignment = 'W' + avg_alignment
                    else:
                        avg_alignment = 'D' + avg_alignment
                elif(cs==2 or cs==4):
                    i=i-1
                    if(cs==2):
                        avg_alignment = 'V' + avg_alignment
                    else:
                        avg_alignment = 'I' + avg_alignment
                tracked_path.append([i,j])
            return avg_alignment, tracked_path

def print_cluster_average_alignments(aligner):
    aligner.gene_clusters_average_alignments = {}
    for i in range(len(aligner.gene_clusters)):
        average_alignment, avg_path =  get_cluster_average_alignments(aligner, aligner.gene_clusters[i] )
        print('cluster: ', i, average_alignment, '(',len(aligner.gene_clusters[i]), 'genes)')
        aligner.gene_clusters_average_alignments[i] = average_alignment


print_cluster_average_alignments(aligner)

# # To access the genes in a particular cluster
# cluster_id = 0
# print(aligner.gene_clusters[cluster_id]) 

# # To print all gene alignments in the cluster
# aligner.show_cluster_alignment_strings(cluster_id)

# ---------------- Clustering genes with df -----
records = []
for cluster_id, gene_list in aligner.gene_clusters.items():
    for gene in gene_list:
        gene_obj   = aligner.results_map[gene]
        alignment  = gene_obj.alignment_str
        records.append({
            'gene': gene,
            'cluster': cluster_id,
            'alignment': alignment
        })

df = pd.DataFrame(records)      # 三列：gene、cluster、alignment
print(df.head())
df.to_csv('gene_cluster_alignment.csv', sep='\t', index=False)
# Out:
# cluster:  0 IIIIIIIMMMMMMMWWIWWWWWW ( 129 genes)
# cluster:  1 IDDDDDDDMMMMMMMIIMIVVV ( 253 genes)
# cluster:  2 MIVVMMVVMVDVVVVIDDDDDDDDDD ( 531 genes)
# cluster:  3 IIIDIIVMMMMMMMMIDDDDDD ( 1372 genes)
# cluster:  4 MMMMMMMMMMMMMMM ( 2322 genes)
# cluster:  5 MMMMMMWWWWWIWWWWIIIIIIII ( 1212 genes)
# cluster:  6 IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD ( 749 genes)
# cluster:  7 MMIIMVVVVVVDDMMMMWWWWWW ( 4 genes)
# cluster:  8 IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD ( 11 genes)
#          gene  cluster                alignment
# 0  Ga01g00013        3    MMIIIIIMMMMMMMIDDDDDD
# 1  Ga01g00062        3    IIIIMMMMMMMMMIDIDDDDD
# 2  Ga01g00123        3  MVVVVVVMMMMMMIDIDDDDDDD
# 3  Ga01g00248        3   IIIDIIMMMMMMMMIIDDDDDD
# 4  Ga01g00223        3     MIIIIMMMMMMDDDDDMMMI

# %% [markdown]
# Print the aggregate (average) cell-level alignments for each cluster

# %%
ClusterUtils.print_cluster_average_alignments(aligner)
# Out:
# cluster:  0 IIIIIIIMMMMMMMWWIWWWWWW ( 129 genes)
# cluster:  1 IDDDDDDDMMMMMMMIIMIVVV ( 253 genes)
# cluster:  2 MIVVMMVVMVDVVVVIDDDDDDDDDD ( 531 genes)
# cluster:  3 IIIDIIVMMMMMMMMIDDDDDD ( 1372 genes)
# cluster:  4 MMMMMMMMMMMMMMM ( 2322 genes)
# cluster:  5 MMMMMMWWWWWIWWWWIIIIIIII ( 1212 genes)
# cluster:  6 IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD ( 749 genes)
# cluster:  7 MMIIMVVVVVVDDMMMMWWWWWW ( 4 genes)
# cluster:  8 IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD ( 11 genes)

# %%
# # To access the genes in a particular cluster
# cluster_id = 0
# print(aligner.gene_clusters[cluster_id]) 

# # To print all gene alignments in the cluster
# aligner.show_cluster_alignment_strings(cluster_id)

# %%
# ------------------ subset ------
os.makedirs("cluster", exist_ok=True)
for cluster in df['cluster'].unique():
    print(f"Subset: {cluster}")
    GENE_SUBSET = df[df['cluster'] == cluster]['gene']
    # Average alignment of any given subset of genes
    aligner.get_aggregate_alignment_for_subset(GENE_SUBSET)
    plt.savefig(
        f'cluster/aggregate_alignment_{cluster}_{prefix_ref}_vs_{prefix_query}.pdf',
        bbox_inches='tight'
    )
    plt.show()
    plt.close('all')
# Out:
# Subset: 3
# Average Alignment:  IIIDIIVMMMMMMMMIDDDDDD (cell-level)
# Subset: 0
# Average Alignment:  IIIIIIIMMMMMMMWWIWWWWWW (cell-level)
# Subset: 6
# Average Alignment:  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD (cell-level)
# Subset: 4
# Average Alignment:  MMMMMMMMMMMMMMM (cell-level)
# Subset: 2
# Average Alignment:  MIVVMMVVMVDVVVVIDDDDDDDDDD (cell-level)
# Subset: 5
# Average Alignment:  MMMMMMWWWWWIWWWWIIIIIIII (cell-level)
# Subset: 1
# Average Alignment:  IDDDDDDDMMMMMMMIIMIVVV (cell-level)
# Subset: 8
# Average Alignment:  IIIDIDIDIDIIIIIIIIIDDDDDDDDDDD (cell-level)
# Subset: 7
# Average Alignment:  MMIIMVVVVVVDDMMMMWWWWWW (cell-level)

# %%
# # To get the cluster id of an alignment object, e.g. TNF, 
# aligner.results_map['Ga01g01085'].cluster_id

# %%
# ----------------------- Save log.txt ---------------------
import sys
from contextlib import redirect_stdout

# 打开一个追加模式文件
log_file = open('log.txt', 'a', buffering=1)  # buffering=1 行缓冲，实时写盘
with redirect_stdout(log_file):
    aligner.get_aggregate_alignment()
    print()
    df = aligner.get_stat_df()
    print()
    print_cluster_average_alignments(aligner)
    


log_file.close()

# %%
# ---------------------- How to save aligner file? -------------
import pickle

with open(f'aligner_{prefix_ref}_vs_{prefix_query}.pkl', 'wb') as f:
    pickle.dump(aligner, f)
    
# with open('aligner.pkl', 'rb') as f:
#     aligner = pickle.load(f)

# %% [markdown]
# ### Average alignment of any given subset of genes
# e.g. `gene_list[40:60]` or a specific gene set in a specific pathway, e.g. EMT

# %%
# GENE_SUBSET = gene_list[40:60]
# aligner.get_aggregate_alignment_for_subset(GENE_SUBSET)

# %% [markdown]
# ###  Exploring alignment and trends of a given gene set

# %% [markdown]
# Following calls a wrapper to extract a specified pathway gene set from msigdb database via blitzgsea package (https://github.com/MaayanLab/blitzgsea)

# %%
# IGS = PathwayAnalyser.InterestingGeneSets(gene_list) 
# #IGS.get_available_pathway_list('KEGG_2021_Human')
# #IGS.get_available_pathway_list('MSigDB_Hallmark_2020')

# %% [markdown]
# You could also add a new library by calling below. <br>

# %%
# ===== Check available libraries in enrichr

#import blitzgsea
#blitzgsea.enrichr.print_libraries()

# ===== Add a selected library

#library_name = "GO_Molecular_Function_2021"
#IGS.add_library(blitzgsea.enrichr.get_library(library_name), library_name)

# %% [markdown]
# #### Check the aggregate alignment and interpolated gene expression trends for a given pathway gene set as below.

# %%
# IGS.add_new_set_from_msigdb('MSigDB_Hallmark_2020', 'Epithelial Mesenchymal Transition', user_setname='EMT')

# %%
# PathwayAnalyser.get_pathway_alignment_stat(aligner, IGS.SETS['EMT'], 'EMT', cluster=True, FIGSIZE=(3,6))

# %%
# PathwayAnalyser.get_pathway_alignment_stat(aligner, gene_list[0:20], 'EMT', cluster=True, FIGSIZE=(3,6))
